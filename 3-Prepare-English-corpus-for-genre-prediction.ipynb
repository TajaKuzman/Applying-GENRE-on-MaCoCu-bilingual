# %%
# install the libraries necessary for data wrangling, prediction and result analysis
import json
import numpy as np
import pandas as pd
import logging
import time
import matplotlib.pyplot as plt
from sklearn import metrics
from sklearn.metrics import classification_report, confusion_matrix, f1_score,precision_score, recall_score
import torch
from numba import cuda

# Install transformers
# (this needs to be done on Kaggle each time you start the session)
#!pip install -q transformers

# Install the simpletransformers
#!pip install -q simpletransformers
from simpletransformers.classification import ClassificationModel

# Install wandb
#!pip install -q wandb
import wandb

# Login to wandb
wandb.login()
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: tajak (use `wandb login --relogin` to force relogin)
# True

# %%
# Open csv file
corpus_path = "Macocu-sl-en-doc-format.csv"

corpus_df = pd.read_csv(corpus_path, sep = "\t")

corpus_df.head(2)
# Out:
#    Unnamed: 0 biroamer_entities translation_direction  \
# 0     2584979                No               sl-orig
# 1     1212933                No               sl-orig
#
#                          en_source en_var_doc en_var_dom  \
# 0  http://15.liffe.si/?lang_chg=en          B          B
# 1  http://16.liffe.si/?lang_chg=en          B          B
#
#                                       sl_source    en_domain    sl_domain  \
# 0               http://15.liffe.si/?lang_chg=sl  15.liffe.si  15.liffe.si
# 1  http://16.liffe.si/index.php?menu_item=domov  16.liffe.si  16.liffe.si
#
#   same_domains        different_domains  average_score  \
# 0          yes  15.liffe.si 15.liffe.si       0.936808
# 1          yes  16.liffe.si 16.liffe.si       0.900000
#
#                                               en_doc  \
# 0  It went out with a bang. The evening sparkled ...
# 1  Some days ago the organisers of the 17th Liffe...
#
#                                               sl_doc  en_length  sl_length
# 0  Končalo se je razburljivo in z razkošjem. Veče...        601        488
# 1  Pred dnevi smo se iz 59. mednarodnega filmskeg...        293        184

# %%
# See corpus size
corpus_df.shape
# Out:
# (104853, 16)

# %%
import os
os.environ["TOKENIZERS_PARALLELISM"] = "false"

# %%
# Initialize Wandb
run = wandb.init(project="X-GENRE classifiers", entity="tajak", name="testing-trained-model")
# Out:
# wandb version 0.13.2 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.12.11
# Run data is saved locally in <code>/home/tajak/Applying-GENRE-on-MaCoCu-bilingual/wandb/run-20220908_152041-28fw5l12</code>
# Syncing run <strong><a href="https://wandb.ai/tajak/X-GENRE%20classifiers/runs/28fw5l12" target="_blank">testing-trained-model</a></strong> to <a href="https://wandb.ai/tajak/X-GENRE%20classifiers" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>

# %%
# Load the trained model from Wandb
model_name = "tajak/X-GENRE classifiers/X-GENRE-classifier"
# Use the latest version of the model
model_at = run.use_artifact(model_name + ":latest")
# Download the directory
model_dir = model_at.download()

# Loading a local save
model = ClassificationModel(
    "xlmroberta", model_dir)
# Out:
# wandb: Downloading large artifact X-GENRE-classifier:latest, 1081.88MB. 8 files... Done. 0:0:0
# /home/tajak/anaconda3/lib/python3.9/site-packages/simpletransformers/classification/classification_model.py:459: UserWarning: use_multiprocessing automatically disabled as xlmroberta fails when using multiprocessing for feature conversion.
#   warnings.warn(

# %%
corpus_df.shape[0]
# Out:
# 104853

# %%
def predict(dataframe, file_path):
    """
    This function takes the dataframe with English documents in the en_doc column, prepared in previous notebooks, and applies the trained model on it to infer predictions. It prints the time that it took to predict to all instances. It saves the results as a new column in the dataframe and returns the dataframe.

    Args:
    - dataframe (pandas DataFrame)
    - file_path: the path to the new CSV file with predictions
    """
    # Calculate the model's predictions
    def make_prediction(input_string):
        return model.predict([input_string])[0][0]

    print("Prediction started.")
    start_time = time.time()

    y_pred = dataframe.en_doc.apply(make_prediction)

    prediction_time = round((time.time() - start_time)/60,2)

    print(f"Prediction completed. It took {prediction_time} minutes for {dataframe.shape[0]} instances - {prediction_time/dataframe.shape[0]} minutes per one instance.")
    
    dataframe["X-GENRE"] = y_pred

    # Save the new dataframe which contains the y_pred values as well
    dataframe.to_csv(f"{file_path}", sep="\t")

    return dataframe

# %%
# Try the code on a sample of the corpus
sample_corpus = corpus_df.sample(n = 20)

sample_corpus.shape
# Out:
# (20, 16)

# %%
sample_predicted = predict(sample_corpus, "sample-corpus-predicted.csv")
# Out:
# Prediction started.
# Prediction completed. It took 0.36 minutes for 20 instances - 0.018 minutes per one instance.

# %% [markdown]
# Prediction took 12 seconds per instance - it would take 350 hours (14 days) to predict everything.

# %%
sample_predicted
# Out:
#         Unnamed: 0 biroamer_entities translation_direction  \
# 63302      1185598                No               sl-orig
# 78201       990862                No               en-orig
# 78109       987119                No               sl-orig
# 36536      1026384                No               sl-orig
# 101032      105985                No               sl-orig
# 39239       162410                No               sl-orig
# 49455      1399933                No               sl-orig
# 73006      2015776                No               sl-orig
# 73806      2555266                No               sl-orig
# 16840       240401               Yes               sl-orig
# 64946      3135797                No               sl-orig
# 6153       1710361                No               sl-orig
# 11262       504596                No               sl-orig
# 97781      2005026                No               sl-orig
# 9827       2356156                No               en-orig
# 44414      1139284                No               sl-orig
# 51549      3107834                No               en-orig
# 39822      1651362                No               sl-orig
# 43999       697941                No               sl-orig
# 70773       303789                No               sl-orig
#
#                                                 en_source en_var_doc  \
# 63302   https://www.bankingsupervision.europa.eu/banki...        UNK
# 78201   https://www.husqvarna.com/au/parts-accessories...          B
# 78109      https://www.hoteltriglavbled.si/en/contact-us/          B
# 36536   https://druzinski-izleti.si/en/regions/coastal...          A
# 101032  https://www.us-rs.si/decision/?lang=en&amp;vr%...          B
# 39239   https://eur-lex.europa.eu/legal-content/EN/TXT...          B
# 49455   https://oblacila.si/hollister-hollister-majica...        MIX
# 73006   https://www.fdv.uni-lj.si/en/library/digital-l...          A
# 73806   https://www.fhs.upr.si//en/research/institute-...          A
# 16840              http://www.goricane.si/en/environment/        UNK
# 64946   https://www.booking.com/landmark/si/the-cave-u...        UNK
# 6153                http://nova.maska.si/en/?redirect=555        MIX
# 11262   http://www.andrejkovacic.com/index.php?option=...        UNK
# 97781   https://www.studio-list.si/de/projects/renovie...          A
# 9827    http://test2.1ka.si/d/en/help/faq/why-is-it-ne...        UNK
# 44414   https://kons-platforma.org/en/dogodki/robotic-...        UNK
# 51549   https://oblacila.si/under-armour-under-armour-...          A
# 39822   https://eur-lex.europa.eu/legal-content/GA/TXT...          B
# 43999   https://izrk.zrc-sazu.si/en/programi-in-projek...          B
# 70773   https://www.europarl.europa.eu/doceo/document/...        UNK
#
#        en_var_dom                                          sl_source  \
# 63302           B  https://www.bankingsupervision.europa.eu/banki...
# 78201           B  https://www.husqvarna.com/si/pribor-dodatna-op...
# 78109           B           https://www.hoteltriglavbled.si/kontakt/
# 36536         MIX  https://druzinski-izleti.si/regije/obalno-kras...
# 101032          B  https://www.us-rs.si/odlocitev?vd=UP&amp;vr%5B...
# 39239           B  https://eur-lex.europa.eu/legal-content/SL/TXT...
# 49455         MIX  https://oblacila.si/mavi-mavi-majica-crna__UrZ...
# 73006         MIX  https://www.fdv.uni-lj.si/knjiznica/digitalna-...
# 73806         MIX  https://www.fhs.upr.si/sl/raziskovanje/institu...
# 16840           B                  http://www.goricane.si/sl/okolje/
# 64946           A  https://www.booking.com/landmark/si/the-cave-u...
# 6153            B              http://nova.maska.si/sl/?redirect=555
# 11262           B  http://www.andrejkovacic.com/slo/index.php?opt...
# 97781           A  https://www.studio-list.si/projects/prenova-go...
# 9827            B  http://test2.1ka.si/d/sl/pomoc/pogosta-vprasan...
# 44414         MIX  https://kons-platforma.org/dogodki/?type=works...
# 51549         MIX  https://oblacila.si/comma-comma-hlace-marine__...
# 39822           B  https://eur-lex.europa.eu/legal-content/SL/TXT...
# 43999         MIX  https://izrk.zrc-sazu.si/sl/programi-in-projek...
# 70773           B  https://www.europarl.europa.eu/doceo/document/...
#
#                            en_domain                     sl_domain  \
# 63302   bankingsupervision.europa.eu  bankingsupervision.europa.eu
# 78201                  husqvarna.com                 husqvarna.com
# 78109            hoteltriglavbled.si           hoteltriglavbled.si
# 36536            druzinski-izleti.si           druzinski-izleti.si
# 101032                      us-rs.si                      us-rs.si
# 39239              eur-lex.europa.eu             eur-lex.europa.eu
# 49455                    oblacila.si                   oblacila.si
# 73006                  fdv.uni-lj.si                 fdv.uni-lj.si
# 73806                     fhs.upr.si                    fhs.upr.si
# 16840                    goricane.si                   goricane.si
# 64946                    booking.com                   booking.com
# 6153                   nova.maska.si                 nova.maska.si
# 11262              andrejkovacic.com             andrejkovacic.com
# 97781                 studio-list.si                studio-list.si
# 9827                    test2.1ka.si                  test2.1ka.si
# 44414             kons-platforma.org            kons-platforma.org
# 51549                    oblacila.si                   oblacila.si
# 39822              eur-lex.europa.eu             eur-lex.europa.eu
# 43999               izrk.zrc-sazu.si              izrk.zrc-sazu.si
# 70773             europarl.europa.eu            europarl.europa.eu
#
#        same_domains                                  different_domains  \
# 63302           yes  bankingsupervision.europa.eu bankingsupervisio...
# 78201           yes                        husqvarna.com husqvarna.com
# 78109           yes            hoteltriglavbled.si hoteltriglavbled.si
# 36536           yes            druzinski-izleti.si druzinski-izleti.si
# 101032          yes                                  us-rs.si us-rs.si
# 39239           yes                eur-lex.europa.eu eur-lex.europa.eu
# 49455           yes                            oblacila.si oblacila.si
# 73006           yes                        fdv.uni-lj.si fdv.uni-lj.si
# 73806           yes                              fhs.upr.si fhs.upr.si
# 16840           yes                            goricane.si goricane.si
# 64946           yes                            booking.com booking.com
# 6153            yes                        nova.maska.si nova.maska.si
# 11262           yes                andrejkovacic.com andrejkovacic.com
# 97781           yes                      studio-list.si studio-list.si
# 9827            yes                          test2.1ka.si test2.1ka.si
# 44414           yes              kons-platforma.org kons-platforma.org
# 51549           yes                            oblacila.si oblacila.si
# 39822           yes                eur-lex.europa.eu eur-lex.europa.eu
# 43999           yes                  izrk.zrc-sazu.si izrk.zrc-sazu.si
# 70773           yes              europarl.europa.eu europarl.europa.eu
#
#         average_score                                             en_doc  \
# 63302        0.896375  In the Single Supervisory Mechanism, the ECB d...
# 78201        0.938571  Exclusively designed by Husqvarna the T35 Univ...
# 78109        0.914462  We encourage Green Mobility, therefore we reco...
# 36536        0.926381  Route Description Rihemberk Castle is one of t...
# 101032       0.830982  Administrative Offences Act (Official Gazette ...
# 39239        0.949970  It aims to adapt EU law to fight terrorism in ...
# 49455        0.797500  The product on the mannequin is M size. T-shir...
# 73006        0.704500  Unit of additional literature: Author: Hill, C...
# 73806        0.940133  The head of the Institute for Intercultural St...
# 16840        0.920000  Green on white The Goričane paper mill has bas...
# 64946        0.946143  Set on a working goat farm, Dolinar Krainer is...
# 6153         0.919786  Giving space to young and emerging as well as ...
# 11262        0.811286  As adults we are taught to use too much muscle...
# 97781        0.923200  The renovated guesthouse is, in comparison to ...
# 9827         0.935538  Why is it necessary to enable Javascript? The ...
# 44414        0.899059  Workshop for kids 7+ at MC Oton, Novo Mesto Wo...
# 51549        0.843889  They are crafted with flat lock seams to preve...
# 39822        0.927156  Having regard to Directive 2004/49/EC of the E...
# 43999        0.927429  Aquifers with karst porosity are unique hydrog...
# 70773        0.958600  CHAPTER 6: BUDGETARY PROCEDURES Rule 98: Imple...
#
#                                                    sl_doc  en_length  \
# 63302   ECB v okviru enotnega mehanizma nadzora neposr...        118
# 78201   Glava trimerja T35, ki jo je ekskluzivno zasno...        143
# 78109   Spodbujamo zeleno mobilnost, zato vsem gostom ...        186
# 36536   Opis poti Grad Rihemberk je najmogočnejši in e...        420
# 101032  Prepoved diskriminacije v enakem obsegu določa...       9587
# 39239   Prečiščena različica Pogodbe o Evropski uniji ...        780
# 49455   Superdry Vintage Logo Linear LS Tee je moška k...        160
# 73006                  Foreign Policy Obvezna literatura:         83
# 73806   Predstojnica Inštituta za medkulturne študije ...        335
# 16840   Zeleno na belem Družba Goričane posluje v skla...        168
# 64946   Kmetija Dolinar Krainer je delovna kmetija na ...        136
# 6153    Glavni cilj je ponuditi prostor mladim neuvelj...        358
# 11262   Večina odraslih se preko izjemnega števila sug...        151
# 97781   Prenovljeno gostišče je, za razliko od starega...        101
# 9827    Zakaj je nujno omogočiti Javascript? Storitev ...        265
# 44414   Delavnica za 9+ v Ljubljani, zbirno mesto pred...        313
# 51549   Pajkice imajo visok pas za boljši oprijem. Opr...        153
# 39822   Ta uredba začne veljati 20. dan po objavi v Ur...       2565
# 43999   Vodonosniki s kraško poroznostjo so edinstveni...        423
# 70773   POGLAVJE 7 : NOTRANJI PRORAČUNSKI POSTOPKI Pre...         84
#
#         sl_length                  X-GENRE
# 63302          98                Promotion
# 78201          70                Promotion
# 78109         168              Instruction
# 36536         328  Information/Explanation
# 101032        961                    Legal
# 39239         947  Information/Explanation
# 49455          93                Promotion
# 73006           4  Information/Explanation
# 73806         289  Information/Explanation
# 16840         110  Information/Explanation
# 64946         152                Promotion
# 6153          337                     News
# 11262         222  Information/Explanation
# 97781         119  Information/Explanation
# 9827          240              Instruction
# 44414          78                Promotion
# 51549          77                Promotion
# 39822         417                    Legal
# 43999         373  Information/Explanation
# 70773          26                    Legal

# %%
sample_predicted["X-GENRE"].value_counts(normalize=True)
# Out:
# Information/Explanation    0.40
# Promotion                  0.30
# Legal                      0.15
# Instruction                0.10
# News                       0.05
# Name: X-GENRE, dtype: float64
