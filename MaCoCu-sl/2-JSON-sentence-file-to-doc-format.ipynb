# %%
import pandas as pd
import numpy as np
import regex as re
import json

# %% [markdown]
# ## Preparation of document format from sentence format

# %%
# Import json
with open("Macocu-sl-en.json", "r") as file:
	tus_content = json.load(file)

# %%
# Convert data to a dataframe

corpus_df = pd.DataFrame(tus_content)

corpus_df.head()
# Out:
#    score_bicleaner_ai biroamer_entities translation_direction  \
# 0               0.950                No               sl-orig
# 1               0.929                No               en-orig
# 2               0.950                No               sl-orig
# 3               0.984                No               sl-orig
# 4               0.886                No               sl-orig
#
#                                            en_source en_par_id  \
# 0                 http://www.damapapir.si/en/ecology     p10s2
# 1  https://www.mesimedical.com/mesi-mtablet/mesi-...     p38s0
# 2         https://www.uirs.si/en-us/About-us/Mission     p33s0
# 3  https://www.visitkras.info/en/divaca-karst-nat...     p32s1
# 4  https://fotoformat.si/en/dslr-cameras/7226-nik...    p137s0
#
#                                               en_par en_var_doc en_var_dom  \
# 0  This significantly contributes to a clean and ...          B        MIX
# 1  MESI mTABLET TBI is not only an advanced Toe-B...        UNK          B
# 2  UIRS has a Research Programme Group which is c...          B        MIX
# 3  You can start the trail at different points, a...          B          B
# 4  -3 to +1 EV in steps of 1/3 or 1/2 EV, in P, S...          A          A
#
#                                            sl_source sl_par_id  \
# 0               http://www.damapapir.si/sl/ekologija     p10s2
# 1  https://www.mesimedical.com/sl/mesi-mtablet/me...     p31s0
# 2                     https://www.uirs.si/Poslanstvo     p33s0
# 3  https://www.visitkras.info/krasoslovna-naravos...     p32s1
# 4  https://www.pikto.si/proizvodi/13860/nikon-dig...    p101s0
#
#                                               sl_par
# 0  S tem bomo preprečili onesnaževanje narave in ...
# 1  MESI mTABLET TBI ni samo napredna naprava za m...
# 2  Na UIRS deluje programska skupina, ki je s str...
# 3  Pot, ki jo lahko začnete na različnih točkah, ...
# 4  Lahko jo prilagodite od –3 do +1 EV v korakih ...

# %%
# Analyze distribution
corpus_df.describe(include="all")
# Out:
#         score_bicleaner_ai biroamer_entities translation_direction  \
# count         3.176311e+06           3176311               3176311
# unique                 NaN                 2                     2
# top                    NaN                No               sl-orig
# freq                   NaN           2897662               2812317
# mean          8.809970e-01               NaN                   NaN
# std           1.299268e-01               NaN                   NaN
# min           5.000000e-01               NaN                   NaN
# 25%           8.250000e-01               NaN                   NaN
# 50%           9.440000e-01               NaN                   NaN
# 75%           9.760000e-01               NaN                   NaN
# max           9.940000e-01               NaN                   NaN
#
#                                                 en_source en_par_id  \
# count                                             3176311   3176311
# unique                                             285892     93755
# top     http://nl.ijs.si/ME/Vault/V3/htm/mte-cesdoc-mt...     p26s0
# freq                                                 5112     36423
# mean                                                  NaN       NaN
# std                                                   NaN       NaN
# min                                                   NaN       NaN
# 25%                                                   NaN       NaN
# 50%                                                   NaN       NaN
# 75%                                                   NaN       NaN
# max                                                   NaN       NaN
#
#                                                    en_par en_var_doc  \
# count                                             3176311    3176311
# unique                                            2379921          4
# top     You should consider whether you understand how...          B
# freq                                                  745    1640246
# mean                                                  NaN        NaN
# std                                                   NaN        NaN
# min                                                   NaN        NaN
# 25%                                                   NaN        NaN
# 50%                                                   NaN        NaN
# 75%                                                   NaN        NaN
# max                                                   NaN        NaN
#
#        en_var_dom                                          sl_source  \
# count     3176311                                            3176311
# unique          4                                             456366
# top             B  http://nl.ijs.si/ME/Vault/V3/htm/mte-cesdoc-mt...
# freq      1967189                                               4294
# mean          NaN                                                NaN
# std           NaN                                                NaN
# min           NaN                                                NaN
# 25%           NaN                                                NaN
# 50%           NaN                                                NaN
# 75%           NaN                                                NaN
# max           NaN                                                NaN
#
#        sl_par_id                                             sl_par
# count    3176311                                            3176311
# unique     86818                                            2542560
# top        p26s0  Izdelana je iz prijetne mešanice naravnega in ...
# freq       33594                                                207
# mean         NaN                                                NaN
# std          NaN                                                NaN
# min          NaN                                                NaN
# 25%          NaN                                                NaN
# 50%          NaN                                                NaN
# 75%          NaN                                                NaN
# max          NaN                                                NaN

# %% [markdown]
# #### Bi-Cleaner Scores on sentence level
#
# As we can see from the column on score_bicleaner_ai, it seems that there are no sentences with score lower than 0.5 - they must have been already filtered out? (?). We can also see, that was majority of sentences were originally written in Slovene (based on translation_direction), and that 700 English sentences and 200 Slovene sentences are repeated which could indicate some errors.

# %%
# Sort by english url and then by en_par_id to order the paragraphs into texts
corpus_df = corpus_df.sort_values(by = ["en_source", "en_par_id"])

corpus_df
# Out:
#          score_bicleaner_ai biroamer_entities translation_direction  \
# 2584979               0.947                No               sl-orig
# 3046105               0.974               Yes               sl-orig
# 1756060               0.908               Yes               sl-orig
# 3012889               0.969                No               sl-orig
# 2928121               0.973               Yes               sl-orig
# ...                     ...               ...                   ...
# 3139299               0.934                No               sl-orig
# 642519                0.911                No               sl-orig
# 263106                0.718                No               sl-orig
# 485460                0.744                No               sl-orig
# 1465464               0.683                No               sl-orig
#
#                                                  en_source en_par_id  \
# 2584979                    http://15.liffe.si/?lang_chg=en     p43s0
# 3046105                    http://15.liffe.si/?lang_chg=en     p43s1
# 1756060                    http://15.liffe.si/?lang_chg=en     p44s0
# 3012889                    http://15.liffe.si/?lang_chg=en     p45s0
# 2928121                    http://15.liffe.si/?lang_chg=en     p45s1
# ...                                                    ...       ...
# 3139299  https://塞尔维亚.realigro.asia/%e5%87%ba%e5%94%ae/...    p105s1
# 642519   https://巴西.realigro.asia/%e5%87%ba%e7%a7%9f/%e...     p67s2
# 263106   https://罗马尼亚.realigro.asia/%e5%87%ba%e5%94%ae/...     p76s1
# 485460   https://西班牙.realigro.asia/%e5%87%ba%e5%94%ae/%...    p103s0
# 1465464  https://西班牙.realigro.asia/%e5%87%ba%e5%94%ae/%...    p127s0
#
#                                                     en_par en_var_doc  \
# 2584979                           It went out with a bang.          B
# 3046105  The evening sparkled with glitter and gold and...          B
# 1756060  Dashing in their black ties and led by eminent...          B
# 3012889  But the film crowd gathered with but one purpo...          B
# 2928121  First the FIPRESCI jury, of the International ...          B
# ...                                                    ...        ...
# 3139299  The apartment consists of a living room with a...        UNK
# 642519   Are you in need of private or business finance...        UNK
# 263106                       Price 2400 euros per hectare.        UNK
# 485460   ID:R-1470 Two rooms, close to the sea Two bedr...        UNK
# 1465464  ID:TH-150 For sale a nice 115 m2 apartment wit...        UNK
#
#         en_var_dom                                          sl_source  \
# 2584979          B                    http://15.liffe.si/?lang_chg=sl
# 3046105          B                    http://15.liffe.si/?lang_chg=sl
# 1756060          B                    http://15.liffe.si/?lang_chg=sl
# 3012889          B                    http://15.liffe.si/?lang_chg=sl
# 2928121          B                    http://15.liffe.si/?lang_chg=sl
# ...            ...                                                ...
# 3139299          A  https://www.nepremicnine.net/oglasi-prodaja/ko...
# 642519         UNK  https://www.knjiznica-velenje.si/events/kaj-mo...
# 263106         UNK  https://kristijanhrastar.kmeckiglas.com/post/2...
# 485460         UNK  http://www.oglasi.si/oglas_nepremicnine/apartm...
# 1465464        UNK  http://www.oglasi.si/oglas_nepremicnine/apartm...
#
#         sl_par_id                                             sl_par
# 2584979     p43s0          Končalo se je razburljivo in z razkošjem.
# 3046105     p43s1  Večer je bleščavo mežikal in Gallusova dvorana...
# 1756060     p44s0  Simfonični orkester RTV Slovenija je eleganten...
# 3012889     p45s0  Filmski navdušenci pa so se zbrali le z enim n...
# 2928121     p45s1  Najprej je žirija mednarodnega združenja films...
# ...           ...                                                ...
# 3139299     p95s0  Stanovanje obsega: predprostor (hodnik), dnevn...
# 642519       p0s0  Kaj moramo vedeti o osebnih in poslovnih finan...
# 263106      p33s2  Povprečni pridelek naj bi bil 5,9 tone na hektar.
# 485460      p33s0  Apartma se nahaja v okolici Krškega, 50 m do a...
# 1465464     p33s1  Apartma je nov in komplet opremljen, z 4 teras...
#
# [3176311 rows x 11 columns]

# %%
# Add information about domains
domain_re=re.compile(r'^https?://(?:www\.)?(.+?)[/$]')

en_domain_list = [domain_re.search(i).group(1) for i in corpus_df.en_source.to_list()]

en_domain_list[:3]
# Out:
# ['15.liffe.si', '15.liffe.si', '15.liffe.si']

# %%
corpus_df["en_domain"] = en_domain_list

corpus_df.head(2)
# Out:
#          score_bicleaner_ai biroamer_entities translation_direction  \
# 2584979               0.947                No               sl-orig
# 3046105               0.974               Yes               sl-orig
#
#                                en_source en_par_id  \
# 2584979  http://15.liffe.si/?lang_chg=en     p43s0
# 3046105  http://15.liffe.si/?lang_chg=en     p43s1
#
#                                                     en_par en_var_doc  \
# 2584979                           It went out with a bang.          B
# 3046105  The evening sparkled with glitter and gold and...          B
#
#         en_var_dom                        sl_source sl_par_id  \
# 2584979          B  http://15.liffe.si/?lang_chg=sl     p43s0
# 3046105          B  http://15.liffe.si/?lang_chg=sl     p43s1
#
#                                                     sl_par    en_domain
# 2584979          Končalo se je razburljivo in z razkošjem.  15.liffe.si
# 3046105  Večer je bleščavo mežikal in Gallusova dvorana...  15.liffe.si

# %%
# Repeat with Slovene domain
sl_domain_list = [domain_re.search(i).group(1) for i in corpus_df.sl_source.to_list()]
corpus_df["sl_domain"] = sl_domain_list

corpus_df.head(2)
# Out:
#          score_bicleaner_ai biroamer_entities translation_direction  \
# 2584979               0.947                No               sl-orig
# 3046105               0.974               Yes               sl-orig
#
#                                en_source en_par_id  \
# 2584979  http://15.liffe.si/?lang_chg=en     p43s0
# 3046105  http://15.liffe.si/?lang_chg=en     p43s1
#
#                                                     en_par en_var_doc  \
# 2584979                           It went out with a bang.          B
# 3046105  The evening sparkled with glitter and gold and...          B
#
#         en_var_dom                        sl_source sl_par_id  \
# 2584979          B  http://15.liffe.si/?lang_chg=sl     p43s0
# 3046105          B  http://15.liffe.si/?lang_chg=sl     p43s1
#
#                                                     sl_par    en_domain  \
# 2584979          Končalo se je razburljivo in z razkošjem.  15.liffe.si
# 3046105  Večer je bleščavo mežikal in Gallusova dvorana...  15.liffe.si
#
#            sl_domain
# 2584979  15.liffe.si
# 3046105  15.liffe.si

# %%
# Add information whether the domains are the same
corpus_df["same_domains"] = np.where(corpus_df["en_domain"] == corpus_df["sl_domain"], "yes", 'no')

# Add column for domains that are different
corpus_df["different_domains"] = corpus_df["en_domain"] + " " + corpus_df["sl_domain"]

corpus_df.head(2)
# Out:
#          score_bicleaner_ai biroamer_entities translation_direction  \
# 2584979               0.947                No               sl-orig
# 3046105               0.974               Yes               sl-orig
#
#                                en_source en_par_id  \
# 2584979  http://15.liffe.si/?lang_chg=en     p43s0
# 3046105  http://15.liffe.si/?lang_chg=en     p43s1
#
#                                                     en_par en_var_doc  \
# 2584979                           It went out with a bang.          B
# 3046105  The evening sparkled with glitter and gold and...          B
#
#         en_var_dom                        sl_source sl_par_id  \
# 2584979          B  http://15.liffe.si/?lang_chg=sl     p43s0
# 3046105          B  http://15.liffe.si/?lang_chg=sl     p43s1
#
#                                                     sl_par    en_domain  \
# 2584979          Končalo se je razburljivo in z razkošjem.  15.liffe.si
# 3046105  Večer je bleščavo mežikal in Gallusova dvorana...  15.liffe.si
#
#            sl_domain same_domains        different_domains
# 2584979  15.liffe.si          yes  15.liffe.si 15.liffe.si
# 3046105  15.liffe.si          yes  15.liffe.si 15.liffe.si

# %%
corpus_df["same_domains"].value_counts()
# Out:
# yes    2347120
# no      829191
# Name: same_domains, dtype: int64

# %%
# Analyze instances from different domains
corpus_df[corpus_df["same_domains"] != "yes"]["different_domains"] .value_counts()
# Out:
# eur-lex.europa.eu uradni-list.si                 21956
# eur-lex.europa.eu europarl.europa.eu             16475
# europarl.europa.eu eur-lex.europa.eu              8431
# croatiabeachacc.com privatapartmajihrvaska.si     6907
# predsednik.si up-rs.si                            6439
#                                                  ...
# eesc.europa.eu okolje.si                             1
# eesc.europa.eu nova-gorica.si                        1
# eesc.europa.eu plastika-lvp.si                       1
# eesc.europa.eu e-uprava.gov.si                       1
# savacommission.org posavskiobzornik.si               1
# Name: different_domains, Length: 118892, dtype: int64

# %%
# Discard instances that are from different domains
corpus_df = corpus_df[corpus_df["same_domains"] == "yes"]
corpus_df.describe(include="all")
# Out:
#         score_bicleaner_ai biroamer_entities translation_direction  \
# count         2.347120e+06           2347120               2347120
# unique                 NaN                 2                     2
# top                    NaN                No               sl-orig
# freq                   NaN           2144059               2091190
# mean          8.977433e-01               NaN                   NaN
# std           1.197017e-01               NaN                   NaN
# min           5.000000e-01               NaN                   NaN
# 25%           8.650000e-01               NaN                   NaN
# 50%           9.550000e-01               NaN                   NaN
# 75%           9.780000e-01               NaN                   NaN
# max           9.940000e-01               NaN                   NaN
#
#                                                 en_source en_par_id  \
# count                                             2347120   2347120
# unique                                             210217     75347
# top     http://nl.ijs.si/ME/Vault/V3/htm/mte-cesdoc-mt...     p26s0
# freq                                                 4719     31662
# mean                                                  NaN       NaN
# std                                                   NaN       NaN
# min                                                   NaN       NaN
# 25%                                                   NaN       NaN
# 50%                                                   NaN       NaN
# 75%                                                   NaN       NaN
# max                                                   NaN       NaN
#
#                                                    en_par en_var_doc  \
# count                                             2347120    2347120
# unique                                            1945904          4
# top     Manager of personal data: Slovenian Tourist Bo...          B
# freq                                                  491    1267294
# mean                                                  NaN        NaN
# std                                                   NaN        NaN
# min                                                   NaN        NaN
# 25%                                                   NaN        NaN
# 50%                                                   NaN        NaN
# 75%                                                   NaN        NaN
# max                                                   NaN        NaN
#
#        en_var_dom                                          sl_source  \
# count     2347120                                            2347120
# unique          4                                             258401
# top             B  http://nl.ijs.si/ME/Vault/V3/htm/mte-cesdoc-mt...
# freq      1484562                                               4083
# mean          NaN                                                NaN
# std           NaN                                                NaN
# min           NaN                                                NaN
# 25%           NaN                                                NaN
# 50%           NaN                                                NaN
# 75%           NaN                                                NaN
# max           NaN                                                NaN
#
#        sl_par_id                                             sl_par  \
# count    2347120                                            2347120
# unique     70296                                            1933838
# top        p26s0  Izdelana je iz prijetne mešanice naravnega in ...
# freq       29002                                                207
# mean         NaN                                                NaN
# std          NaN                                                NaN
# min          NaN                                                NaN
# 25%          NaN                                                NaN
# 50%          NaN                                                NaN
# 75%          NaN                                                NaN
# max          NaN                                                NaN
#
#                 en_domain          sl_domain same_domains  \
# count             2347120            2347120      2347120
# unique               7301               7301            1
# top     eur-lex.europa.eu  eur-lex.europa.eu          yes
# freq               387442             387442      2347120
# mean                  NaN                NaN          NaN
# std                   NaN                NaN          NaN
# min                   NaN                NaN          NaN
# 25%                   NaN                NaN          NaN
# 50%                   NaN                NaN          NaN
# 75%                   NaN                NaN          NaN
# max                   NaN                NaN          NaN
#
#                           different_domains
# count                               2347120
# unique                                 7301
# top     eur-lex.europa.eu eur-lex.europa.eu
# freq                                 387442
# mean                                    NaN
# std                                     NaN
# min                                     NaN
# 25%                                     NaN
# 50%                                     NaN
# 75%                                     NaN
# max                                     NaN

# %%
# Calculate average bicleaner ai score based on the en_source
corpus_df["average_score"] = corpus_df["score_bicleaner_ai"].groupby(corpus_df['en_source']).transform('mean')

corpus_df.head(2)
# Out:
# /tmp/ipykernel_32490/1031930680.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   corpus_df["average_score"] = corpus_df["score_bicleaner_ai"].groupby(corpus_df['en_source']).transform('mean')
#          score_bicleaner_ai biroamer_entities translation_direction  \
# 2584979               0.947                No               sl-orig
# 3046105               0.974               Yes               sl-orig
#
#                                en_source en_par_id  \
# 2584979  http://15.liffe.si/?lang_chg=en     p43s0
# 3046105  http://15.liffe.si/?lang_chg=en     p43s1
#
#                                                     en_par en_var_doc  \
# 2584979                           It went out with a bang.          B
# 3046105  The evening sparkled with glitter and gold and...          B
#
#         en_var_dom                        sl_source sl_par_id  \
# 2584979          B  http://15.liffe.si/?lang_chg=sl     p43s0
# 3046105          B  http://15.liffe.si/?lang_chg=sl     p43s1
#
#                                                     sl_par    en_domain  \
# 2584979          Končalo se je razburljivo in z razkošjem.  15.liffe.si
# 3046105  Večer je bleščavo mežikal in Gallusova dvorana...  15.liffe.si
#
#            sl_domain same_domains        different_domains  average_score
# 2584979  15.liffe.si          yes  15.liffe.si 15.liffe.si       0.936808
# 3046105  15.liffe.si          yes  15.liffe.si 15.liffe.si       0.936808

# %%
# Join par id and text
corpus_df["en-par-text"] = corpus_df["en_par_id"] + "-" + corpus_df["en_par"]
corpus_df.head(2)
# Out:
# /tmp/ipykernel_32490/3160425621.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   corpus_df["en-par-text"] = corpus_df["en_par_id"] + "-" + corpus_df["en_par"]
#          score_bicleaner_ai biroamer_entities translation_direction  \
# 2584979               0.947                No               sl-orig
# 3046105               0.974               Yes               sl-orig
#
#                                en_source en_par_id  \
# 2584979  http://15.liffe.si/?lang_chg=en     p43s0
# 3046105  http://15.liffe.si/?lang_chg=en     p43s1
#
#                                                     en_par en_var_doc  \
# 2584979                           It went out with a bang.          B
# 3046105  The evening sparkled with glitter and gold and...          B
#
#         en_var_dom                        sl_source sl_par_id  \
# 2584979          B  http://15.liffe.si/?lang_chg=sl     p43s0
# 3046105          B  http://15.liffe.si/?lang_chg=sl     p43s1
#
#                                                     sl_par    en_domain  \
# 2584979          Končalo se je razburljivo in z razkošjem.  15.liffe.si
# 3046105  Večer je bleščavo mežikal in Gallusova dvorana...  15.liffe.si
#
#            sl_domain same_domains        different_domains  average_score  \
# 2584979  15.liffe.si          yes  15.liffe.si 15.liffe.si       0.936808
# 3046105  15.liffe.si          yes  15.liffe.si 15.liffe.si       0.936808
#
#                                                en-par-text
# 2584979                     p43s0-It went out with a bang.
# 3046105  p43s1-The evening sparkled with glitter and go...

# %%
# Find duplicated English sentences that have the same par id
corpus_df[corpus_df["en-par-text"].duplicated(keep=False)]
# Out:
#          score_bicleaner_ai biroamer_entities translation_direction  \
# 62307                 0.794               Yes               sl-orig
# 831882                0.856               Yes               sl-orig
# 2185018               0.546                No               sl-orig
# 2623298               0.975                No               sl-orig
# 918963                0.781                No               sl-orig
# ...                     ...               ...                   ...
# 1381508               0.984                No               en-orig
# 2924267               0.956                No               en-orig
# 3149698               0.984                No               en-orig
# 151207                0.926                No               en-orig
# 751800                0.749                No               en-orig
#
#                                                  en_source en_par_id  \
# 62307                      http://15.liffe.si/?lang_chg=en     p56s0
# 831882                     http://15.liffe.si/?lang_chg=en     p56s0
# 2185018                       http://2007-2013.ita-slo.eu/     p35s2
# 2623298                       http://2007-2013.ita-slo.eu/     p35s2
# 918963              http://2009-2010.isak.si/eng/index.php      p0s0
# ...                                                    ...       ...
# 1381508     https://zwave.si/index.php?_route_=FIB_FGD_212    p455s1
# 2924267  https://zwave.si/index.php?_route_=FibaroWallP...    p443s1
# 3149698  https://zwave.si/index.php?_route_=FibaroWallP...    p443s1
# 151207   https://zwave.si/index.php?_route_=all/AllRF43...    p440s0
# 751800   https://zwave.si/index.php?_route_=all/AllRF43...    p440s0
#
#                                                     en_par en_var_doc  \
# 62307    Jelka Stergel, Liffe Festival Director, attend...          B
# 831882   Jelka Stergel, Liffe Festival Director, attend...          B
# 2185018  CALL FOR INDEPENDENT EXPERTS FOR THE QUALITY A...        UNK
# 2623298  CALL FOR INDEPENDENT EXPERTS FOR THE QUALITY A...        UNK
# 918963   A project for promoting African culture with a...          B
# ...                                                    ...        ...
# 1381508  Each Z-Wave module functions as a wireless rep...        UNK
# 2924267  Each module Z-Wave operates as a wireless repe...          A
# 3149698  Each module Z-Wave operates as a wireless repe...          A
# 151207   This interface will increase the ability to tr...        UNK
# 751800   This interface will increase the ability to tr...        UNK
#
#         en_var_dom                                          sl_source  \
# 62307            B  http://15.liffe.si/?menu_item=podatki&amp;menu...
# 831882           B                    http://15.liffe.si/?lang_chg=sl
# 2185018          B  http://2007-2013.ita-slo.eu/novice_in_informac...
# 2623298          B  http://2007-2013.ita-slo.eu/novice_in_informac...
# 918963           B  http://2009-2010.isak.si/aktualno-novica.php?id=5
# ...            ...                                                ...
# 1381508          A  https://zwave.si/index.php?_route_=Aeotec/AEO-...
# 2924267          A  https://zwave.si/index.php?_route_=Philio-Tech...
# 3149698          A  https://zwave.si/index.php?_route_=sensors/pow...
# 151207           A  https://zwave.si/index.php?_route_=newsletter0...
# 751800           A  https://zwave.si/index.php?_route_=newsletter0...
#
#                  sl_par_id                                             sl_par  \
# 62307                p50s1  Srečala se je z direktorico festivala na Portu...
# 831882   p56s0+p57s0+p57s1  Aktualno Tudi Jelka Stergel je bila na festiva...
# 2185018              p30s0  Javni Poziv za oblikovanje seznama neodvisnih ...
# 2623298              p30s2  JAVNI POZIV ZA IZBOR NEODVISNIH STROKOVNJAKOV ...
# 918963               p10s1  Projekt ISAK je projekt širjenja afriške kultu...
# ...                    ...                                                ...
# 1381508             p442s1  Vsak Z-Wave modul deluje kot brezžični repetit...
# 2924267             p439s5  Ta Z- Wave modul deluje kot brezžični repetito...
# 3149698             p442s1  Vsak Z-Wave modul deluje kot brezžični repetit...
# 151207              p443s1  Ta vmesnik bo povečal zmožnost oddajanja in sp...
# 751800              p438s0  Ta interface nam poveča sposobnost oddajanja i...
#
#                     en_domain             sl_domain same_domains  \
# 62307             15.liffe.si           15.liffe.si          yes
# 831882            15.liffe.si           15.liffe.si          yes
# 2185018  2007-2013.ita-slo.eu  2007-2013.ita-slo.eu          yes
# 2623298  2007-2013.ita-slo.eu  2007-2013.ita-slo.eu          yes
# 918963      2009-2010.isak.si     2009-2010.isak.si          yes
# ...                       ...                   ...          ...
# 1381508              zwave.si              zwave.si          yes
# 2924267              zwave.si              zwave.si          yes
# 3149698              zwave.si              zwave.si          yes
# 151207               zwave.si              zwave.si          yes
# 751800               zwave.si              zwave.si          yes
#
#                                  different_domains  average_score  \
# 62307                      15.liffe.si 15.liffe.si       0.936808
# 831882                     15.liffe.si 15.liffe.si       0.936808
# 2185018  2007-2013.ita-slo.eu 2007-2013.ita-slo.eu       0.770333
# 2623298  2007-2013.ita-slo.eu 2007-2013.ita-slo.eu       0.770333
# 918963         2009-2010.isak.si 2009-2010.isak.si       0.848600
# ...                                            ...            ...
# 1381508                          zwave.si zwave.si       0.975000
# 2924267                          zwave.si zwave.si       0.970000
# 3149698                          zwave.si zwave.si       0.970000
# 151207                           zwave.si zwave.si       0.895250
# 751800                           zwave.si zwave.si       0.895250
#
#                                                en-par-text
# 62307    p56s0-Jelka Stergel, Liffe Festival Director, ...
# 831882   p56s0-Jelka Stergel, Liffe Festival Director, ...
# 2185018  p35s2-CALL FOR INDEPENDENT EXPERTS FOR THE QUA...
# 2623298  p35s2-CALL FOR INDEPENDENT EXPERTS FOR THE QUA...
# 918963   p0s0-A project for promoting African culture w...
# ...                                                    ...
# 1381508  p455s1-Each Z-Wave module functions as a wirel...
# 2924267  p443s1-Each module Z-Wave operates as a wirele...
# 3149698  p443s1-Each module Z-Wave operates as a wirele...
# 151207   p440s0-This interface will increase the abilit...
# 751800   p440s0-This interface will increase the abilit...
#
# [472915 rows x 17 columns]

# %%
# Discard all duplicated English paragraphs with the same par id - this could destroy structure of some of the Slovene texts, but we are interested only in English texts.
corpus_df = corpus_df.drop_duplicates("en-par-text")

# %%
corpus_df.describe(include="all")
# Out:
#         score_bicleaner_ai biroamer_entities translation_direction  \
# count         2.047953e+06           2047953               2047953
# unique                 NaN                 2                     2
# top                    NaN                No               sl-orig
# freq                   NaN           1872834               1818807
# mean          9.052680e-01               NaN                   NaN
# std           1.151669e-01               NaN                   NaN
# min           5.000000e-01               NaN                   NaN
# 25%           8.830000e-01               NaN                   NaN
# 50%           9.600000e-01               NaN                   NaN
# 75%           9.790000e-01               NaN                   NaN
# max           9.940000e-01               NaN                   NaN
#
#                                                 en_source en_par_id  \
# count                                             2047953   2047953
# unique                                             207525     75347
# top     http://nl.ijs.si/ME/Vault/V3/htm/mte-cesdoc-mt...     p26s0
# freq                                                 4276     15844
# mean                                                  NaN       NaN
# std                                                   NaN       NaN
# min                                                   NaN       NaN
# 25%                                                   NaN       NaN
# 50%                                                   NaN       NaN
# 75%                                                   NaN       NaN
# max                                                   NaN       NaN
#
#                                                   en_par en_var_doc  \
# count                                            2047953    2047953
# unique                                           1945904          4
# top     The sweatshirt is made of high quality material.          B
# freq                                                 116    1139607
# mean                                                 NaN        NaN
# std                                                  NaN        NaN
# min                                                  NaN        NaN
# 25%                                                  NaN        NaN
# 50%                                                  NaN        NaN
# 75%                                                  NaN        NaN
# max                                                  NaN        NaN
#
#        en_var_dom                                          sl_source  \
# count     2047953                                            2047953
# unique          4                                             231434
# top             B  http://nl.ijs.si/ME/Vault/V3/htm/mte-cesdoc-mt...
# freq      1324035                                               3912
# mean          NaN                                                NaN
# std           NaN                                                NaN
# min           NaN                                                NaN
# 25%           NaN                                                NaN
# 50%           NaN                                                NaN
# 75%           NaN                                                NaN
# max           NaN                                                NaN
#
#        sl_par_id                                             sl_par  \
# count    2047953                                            2047953
# unique     67428                                            1823951
# top        p26s0  Izdelane so iz trpežnega in rahlo raztegljiveg...
# freq       15665                                                138
# mean         NaN                                                NaN
# std          NaN                                                NaN
# min          NaN                                                NaN
# 25%          NaN                                                NaN
# 50%          NaN                                                NaN
# 75%          NaN                                                NaN
# max          NaN                                                NaN
#
#                 en_domain          sl_domain same_domains  \
# count             2047953            2047953      2047953
# unique               7301               7301            1
# top     eur-lex.europa.eu  eur-lex.europa.eu          yes
# freq               339909             339909      2047953
# mean                  NaN                NaN          NaN
# std                   NaN                NaN          NaN
# min                   NaN                NaN          NaN
# 25%                   NaN                NaN          NaN
# 50%                   NaN                NaN          NaN
# 75%                   NaN                NaN          NaN
# max                   NaN                NaN          NaN
#
#                           different_domains  average_score  \
# count                               2047953   2.047953e+06
# unique                                 7301            NaN
# top     eur-lex.europa.eu eur-lex.europa.eu            NaN
# freq                                 339909            NaN
# mean                                    NaN   9.045701e-01
# std                                     NaN   5.848313e-02
# min                                     NaN   5.000000e-01
# 25%                                     NaN   8.879344e-01
# 50%                                     NaN   9.206226e-01
# 75%                                     NaN   9.406818e-01
# max                                     NaN   9.920000e-01
#
#                            en-par-text
# count                          2047953
# unique                         2047953
# top     p43s0-It went out with a bang.
# freq                                 1
# mean                               NaN
# std                                NaN
# min                                NaN
# 25%                                NaN
# 50%                                NaN
# 75%                                NaN
# max                                NaN

# %%
# Add to each instance from the same en_source joint text from all sentences
corpus_df["en_doc"] = corpus_df["en_par"].groupby(corpus_df['en_source']).transform(' '.join)

corpus_df.head(2)
# Out:
#          score_bicleaner_ai biroamer_entities translation_direction  \
# 2584979               0.947                No               sl-orig
# 3046105               0.974               Yes               sl-orig
#
#                                en_source en_par_id  \
# 2584979  http://15.liffe.si/?lang_chg=en     p43s0
# 3046105  http://15.liffe.si/?lang_chg=en     p43s1
#
#                                                     en_par en_var_doc  \
# 2584979                           It went out with a bang.          B
# 3046105  The evening sparkled with glitter and gold and...          B
#
#         en_var_dom                        sl_source sl_par_id  \
# 2584979          B  http://15.liffe.si/?lang_chg=sl     p43s0
# 3046105          B  http://15.liffe.si/?lang_chg=sl     p43s1
#
#                                                     sl_par    en_domain  \
# 2584979          Končalo se je razburljivo in z razkošjem.  15.liffe.si
# 3046105  Večer je bleščavo mežikal in Gallusova dvorana...  15.liffe.si
#
#            sl_domain same_domains        different_domains  average_score  \
# 2584979  15.liffe.si          yes  15.liffe.si 15.liffe.si       0.936808
# 3046105  15.liffe.si          yes  15.liffe.si 15.liffe.si       0.936808
#
#                                                en-par-text  \
# 2584979                     p43s0-It went out with a bang.
# 3046105  p43s1-The evening sparkled with glitter and go...
#
#                                                     en_doc
# 2584979  It went out with a bang. The evening sparkled ...
# 3046105  It went out with a bang. The evening sparkled ...

# %%
# Repeat with the Slovene text
corpus_df["sl_doc"] = corpus_df["sl_par"].groupby(corpus_df['sl_source']).transform(' '.join)
corpus_df.head(2)
# Out:
#          score_bicleaner_ai biroamer_entities translation_direction  \
# 2584979               0.947                No               sl-orig
# 3046105               0.974               Yes               sl-orig
#
#                                en_source en_par_id  \
# 2584979  http://15.liffe.si/?lang_chg=en     p43s0
# 3046105  http://15.liffe.si/?lang_chg=en     p43s1
#
#                                                     en_par en_var_doc  \
# 2584979                           It went out with a bang.          B
# 3046105  The evening sparkled with glitter and gold and...          B
#
#         en_var_dom                        sl_source sl_par_id  \
# 2584979          B  http://15.liffe.si/?lang_chg=sl     p43s0
# 3046105          B  http://15.liffe.si/?lang_chg=sl     p43s1
#
#                                                     sl_par    en_domain  \
# 2584979          Končalo se je razburljivo in z razkošjem.  15.liffe.si
# 3046105  Večer je bleščavo mežikal in Gallusova dvorana...  15.liffe.si
#
#            sl_domain same_domains        different_domains  average_score  \
# 2584979  15.liffe.si          yes  15.liffe.si 15.liffe.si       0.936808
# 3046105  15.liffe.si          yes  15.liffe.si 15.liffe.si       0.936808
#
#                                                en-par-text  \
# 2584979                     p43s0-It went out with a bang.
# 3046105  p43s1-The evening sparkled with glitter and go...
#
#                                                     en_doc  \
# 2584979  It went out with a bang. The evening sparkled ...
# 3046105  It went out with a bang. The evening sparkled ...
#
#                                                     sl_doc
# 2584979  Končalo se je razburljivo in z razkošjem. Veče...
# 3046105  Končalo se je razburljivo in z razkošjem. Veče...

# %%
# Keep only one example of each text
corpus_df = corpus_df.drop_duplicates("en_doc")

corpus_df.shape
# Out:
# (205785, 19)

# %%
corpus_df.describe(include="all")
# Out:
#         score_bicleaner_ai biroamer_entities translation_direction  \
# count        205785.000000            205785                205785
# unique                 NaN                 2                     2
# top                    NaN                No               sl-orig
# freq                   NaN            179191                178411
# mean              0.865134               NaN                   NaN
# std               0.134490               NaN                   NaN
# min               0.500000               NaN                   NaN
# 25%               0.792000               NaN                   NaN
# 50%               0.926000               NaN                   NaN
# 75%               0.970000               NaN                   NaN
# max               0.993000               NaN                   NaN
#
#                               en_source en_par_id  \
# count                            205785    205785
# unique                           205785     12093
# top     http://15.liffe.si/?lang_chg=en     p26s0
# freq                                  1     10082
# mean                                NaN       NaN
# std                                 NaN       NaN
# min                                 NaN       NaN
# 25%                                 NaN       NaN
# 50%                                 NaN       NaN
# 75%                                 NaN       NaN
# max                                 NaN       NaN
#
#                                                    en_par en_var_doc  \
# count                                              205785     205785
# unique                                             200156          4
# top     The material perfectly diverts sweat and it wi...        UNK
# freq                                                   19     109044
# mean                                                  NaN        NaN
# std                                                   NaN        NaN
# min                                                   NaN        NaN
# 25%                                                   NaN        NaN
# 50%                                                   NaN        NaN
# 75%                                                   NaN        NaN
# max                                                   NaN        NaN
#
#        en_var_dom                                     sl_source sl_par_id  \
# count      205785                                        205785    205785
# unique          4                                        170244     10991
# top             B  https://www.realitica.com/en/listing/2447504     p26s0
# freq        97925                                            13      8692
# mean          NaN                                           NaN       NaN
# std           NaN                                           NaN       NaN
# min           NaN                                           NaN       NaN
# 25%           NaN                                           NaN       NaN
# 50%           NaN                                           NaN       NaN
# 75%           NaN                                           NaN       NaN
# max           NaN                                           NaN       NaN
#
#                                                    sl_par        en_domain  \
# count                                              205785           205785
# unique                                             183477             7300
# top     Nahajate se na arhivskem spletnem mestu Festiv...  rumenestrani.si
# freq                                                   84            16674
# mean                                                  NaN              NaN
# std                                                   NaN              NaN
# min                                                   NaN              NaN
# 25%                                                   NaN              NaN
# 50%                                                   NaN              NaN
# 75%                                                   NaN              NaN
# max                                                   NaN              NaN
#
#               sl_domain same_domains                different_domains  \
# count            205785       205785                           205785
# unique             7300            1                             7300
# top     rumenestrani.si          yes  rumenestrani.si rumenestrani.si
# freq              16674       205785                            16674
# mean                NaN          NaN                              NaN
# std                 NaN          NaN                              NaN
# min                 NaN          NaN                              NaN
# 25%                 NaN          NaN                              NaN
# 50%                 NaN          NaN                              NaN
# 75%                 NaN          NaN                              NaN
# max                 NaN          NaN                              NaN
#
#         average_score                     en-par-text  \
# count   205785.000000                          205785
# unique            NaN                          205785
# top               NaN  p43s0-It went out with a bang.
# freq              NaN                               1
# mean         0.870281                             NaN
# std          0.099500                             NaN
# min          0.500000                             NaN
# 25%          0.823000                             NaN
# 50%          0.900833                             NaN
# 75%          0.943800                             NaN
# max          0.992000                             NaN
#
#                                                    en_doc  \
# count                                              205785
# unique                                             205785
# top     It went out with a bang. The evening sparkled ...
# freq                                                    1
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                                    sl_doc
# count                                              205785
# unique                                             168462
# top     Deloglasnik.si je danes med najbolj obiskanimi...
# freq                                                   44
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN

# %%
# Add information about length
corpus_df["en_length"] = corpus_df.en_doc.str.split().str.len()

corpus_df.head(3)
# Out:
#          score_bicleaner_ai biroamer_entities translation_direction  \
# 2584979               0.947                No               sl-orig
# 1212933               0.899                No               sl-orig
# 598330                0.976               Yes               sl-orig
#
#                                en_source en_par_id  \
# 2584979  http://15.liffe.si/?lang_chg=en     p43s0
# 1212933  http://16.liffe.si/?lang_chg=en     p39s0
# 598330   http://17.liffe.si/?lang_chg=en      p2s0
#
#                                                     en_par en_var_doc  \
# 2584979                           It went out with a bang.          B
# 1212933  Some days ago the organisers of the 17th Liffe...          B
# 598330   17th LIFFe was brought to an end with the best...          B
#
#         en_var_dom                                     sl_source    sl_par_id  \
# 2584979          B               http://15.liffe.si/?lang_chg=sl        p43s0
# 1212933          B  http://16.liffe.si/index.php?menu_item=domov  p39s0+p39s1
# 598330           B               http://17.liffe.si/?lang_chg=sl         p2s0
#
#                                                     sl_par    en_domain  \
# 2584979          Končalo se je razburljivo in z razkošjem.  15.liffe.si
# 1212933  Pred dnevi smo se iz 59. mednarodnega filmskeg...  16.liffe.si
# 598330   S podelitvijo nagrad in predvajanjem Režiserja...  17.liffe.si
#
#            sl_domain same_domains        different_domains  average_score  \
# 2584979  15.liffe.si          yes  15.liffe.si 15.liffe.si       0.936808
# 1212933  16.liffe.si          yes  16.liffe.si 16.liffe.si       0.900000
# 598330   17.liffe.si          yes  17.liffe.si 17.liffe.si       0.957875
#
#                                                en-par-text  \
# 2584979                     p43s0-It went out with a bang.
# 1212933  p39s0-Some days ago the organisers of the 17th...
# 598330   p2s0-17th LIFFe was brought to an end with the...
#
#                                                     en_doc  \
# 2584979  It went out with a bang. The evening sparkled ...
# 1212933  Some days ago the organisers of the 17th Liffe...
# 598330   17th LIFFe was brought to an end with the best...
#
#                                                     sl_doc  en_length
# 2584979  Končalo se je razburljivo in z razkošjem. Veče...        574
# 1212933  Pred dnevi smo se iz 59. mednarodnega filmskeg...        293
# 598330   S podelitvijo nagrad in predvajanjem Režiserja...        445

# %%
corpus_df.en_length.describe()
# Out:
# count    205785.000000
# mean        228.741604
# std        1208.042942
# min           1.000000
# 25%          27.000000
# 50%          75.000000
# 75%         189.000000
# max       98761.000000
# Name: en_length, dtype: float64

# %%
# Add information about Slovene length
corpus_df["sl_length"] = corpus_df.sl_doc.str.split().str.len()

corpus_df.head(3)
# Out:
#          score_bicleaner_ai biroamer_entities translation_direction  \
# 2584979               0.947                No               sl-orig
# 1212933               0.899                No               sl-orig
# 598330                0.976               Yes               sl-orig
#
#                                en_source en_par_id  \
# 2584979  http://15.liffe.si/?lang_chg=en     p43s0
# 1212933  http://16.liffe.si/?lang_chg=en     p39s0
# 598330   http://17.liffe.si/?lang_chg=en      p2s0
#
#                                                     en_par en_var_doc  \
# 2584979                           It went out with a bang.          B
# 1212933  Some days ago the organisers of the 17th Liffe...          B
# 598330   17th LIFFe was brought to an end with the best...          B
#
#         en_var_dom                                     sl_source    sl_par_id  \
# 2584979          B               http://15.liffe.si/?lang_chg=sl        p43s0
# 1212933          B  http://16.liffe.si/index.php?menu_item=domov  p39s0+p39s1
# 598330           B               http://17.liffe.si/?lang_chg=sl         p2s0
#
#          ...    en_domain    sl_domain same_domains        different_domains  \
# 2584979  ...  15.liffe.si  15.liffe.si          yes  15.liffe.si 15.liffe.si
# 1212933  ...  16.liffe.si  16.liffe.si          yes  16.liffe.si 16.liffe.si
# 598330   ...  17.liffe.si  17.liffe.si          yes  17.liffe.si 17.liffe.si
#
#         average_score                                        en-par-text  \
# 2584979      0.936808                     p43s0-It went out with a bang.
# 1212933      0.900000  p39s0-Some days ago the organisers of the 17th...
# 598330       0.957875  p2s0-17th LIFFe was brought to an end with the...
#
#                                                     en_doc  \
# 2584979  It went out with a bang. The evening sparkled ...
# 1212933  Some days ago the organisers of the 17th Liffe...
# 598330   17th LIFFe was brought to an end with the best...
#
#                                                     sl_doc en_length  \
# 2584979  Končalo se je razburljivo in z razkošjem. Veče...       574
# 1212933  Pred dnevi smo se iz 59. mednarodnega filmskeg...       293
# 598330   S podelitvijo nagrad in predvajanjem Režiserja...       445
#
#          sl_length
# 2584979        463
# 1212933        184
# 598330         418
#
# [3 rows x 21 columns]

# %%
# Analyze Slovene length
corpus_df.sl_length.describe()

# %%
# Discard instances that have length less than the median - less than 75
corpus_df = corpus_df[corpus_df["en_length"] > 74]

corpus_df.shape
# Out:
# (103281, 21)

# %%
corpus_df.columns
# Out:
# Index(['score_bicleaner_ai', 'biroamer_entities', 'translation_direction',
#        'en_source', 'en_par_id', 'en_par', 'en_var_doc', 'en_var_dom',
#        'sl_source', 'sl_par_id', 'sl_par', 'en_domain', 'sl_domain',
#        'same_domains', 'different_domains', 'average_score', 'en-par-text',
#        'en_doc', 'sl_doc', 'en_length', 'sl_length'],
#       dtype='object')

# %%
# Discard irrelevant columns
corpus_df = corpus_df.drop(columns = ['score_bicleaner_ai', 'en_par_id', 'en_par', 'sl_par_id', 'sl_par', 'en-par-text', 'same_domains', 'different_domains'])

# %%
# Save the dataframe to csv
corpus_df.to_csv("Macocu-sl-en-doc-format.csv", sep= "\t")

# %% [markdown]
# ## Analysis of prepared corpus
#
# After this preparation, I added additional pre-processing based on the ratio of punctuation per words - see *2.1-Filtering-non-textual.ipynb*. We will now analyse the final file where non-textual texts were removed based on this ratio.

# %%
# Import filtered corpus
corpus_df = pd.read_csv("Macocu-sl-en-doc-format-filtered.csv", sep = "\t", index_col = 0)

corpus_df.head()
# Out:
#         biroamer_entities translation_direction  \
# 2584979                No               sl-orig
# 1212933                No               sl-orig
# 598330                Yes               sl-orig
# 374561                 No               sl-orig
# 642105                Yes               sl-orig
#
#                                    en_source en_var_doc en_var_dom  \
# 2584979      http://15.liffe.si/?lang_chg=en          B          B
# 1212933      http://16.liffe.si/?lang_chg=en          B          B
# 598330       http://17.liffe.si/?lang_chg=en          B          B
# 374561   http://1proti1.mg-lj.si/en/concept/        UNK        UNK
# 642105       http://2006.fdf.si/?lang_chg=en          B          B
#
#                                                  sl_source         en_domain  \
# 2584979                    http://15.liffe.si/?lang_chg=sl       15.liffe.si
# 1212933       http://16.liffe.si/index.php?menu_item=domov       16.liffe.si
# 598330                     http://17.liffe.si/?lang_chg=sl       17.liffe.si
# 374561                    http://1proti1.mg-lj.si/koncept/  1proti1.mg-lj.si
# 642105   http://2006.fdf.si/?menu_item=podatki&amp;menu...       2006.fdf.si
#
#                 sl_domain  average_score  \
# 2584979       15.liffe.si       0.936808
# 1212933       16.liffe.si       0.900000
# 598330        17.liffe.si       0.957875
# 374561   1proti1.mg-lj.si       0.947393
# 642105        2006.fdf.si       0.941667
#
#                                                     en_doc  \
# 2584979  It went out with a bang. The evening sparkled ...
# 1212933  Some days ago the organisers of the 17th Liffe...
# 598330   17th LIFFe was brought to an end with the best...
# 374561   Not interested in showcasing art, 1:1 would be...
# 642105   The 8th International Documentary Film Festiva...
#
#                                                     sl_doc  en_length  \
# 2584979  Končalo se je razburljivo in z razkošjem. Veče...        574
# 1212933  Pred dnevi smo se iz 59. mednarodnega filmskeg...        293
# 598330   S podelitvijo nagrad in predvajanjem Režiserja...        445
# 374561   Koncept 1:1 noče biti razstava v smislu izložb...        769
# 642105   S slovenskim filmom Poročno potovanje se je ko...        423
#
#          sl_length  punct_ratio
# 2584979        463     0.103501
# 1212933        184     0.076220
# 598330         418     0.073930
# 374561         650     0.115178
# 642105          13     0.084567

# %%
# Inspect corpus information
corpus_df.describe(include="all")
# Out:
#        biroamer_entities translation_direction  \
# count             101807                101807
# unique                 2                     2
# top                   No               sl-orig
# freq               89024                 90537
# mean                 NaN                   NaN
# std                  NaN                   NaN
# min                  NaN                   NaN
# 25%                  NaN                   NaN
# 50%                  NaN                   NaN
# 75%                  NaN                   NaN
# max                  NaN                   NaN
#
#                               en_source en_var_doc en_var_dom  \
# count                            101807     101807     101807
# unique                           101807          4          4
# top     http://15.liffe.si/?lang_chg=en          B          B
# freq                                  1      42890      57737
# mean                                NaN        NaN        NaN
# std                                 NaN        NaN        NaN
# min                                 NaN        NaN        NaN
# 25%                                 NaN        NaN        NaN
# 50%                                 NaN        NaN        NaN
# 75%                                 NaN        NaN        NaN
# max                                 NaN        NaN        NaN
#
#                                                 sl_source    en_domain  \
# count                                              101807       101807
# unique                                              92708         6066
# top     https://www.sofascore.com/sl/ekipa/nogomet/vik...  oblacila.si
# freq                                                    9         3600
# mean                                                  NaN          NaN
# std                                                   NaN          NaN
# min                                                   NaN          NaN
# 25%                                                   NaN          NaN
# 50%                                                   NaN          NaN
# 75%                                                   NaN          NaN
# max                                                   NaN          NaN
#
#           sl_domain  average_score  \
# count        101807  101807.000000
# unique         6066            NaN
# top     oblacila.si            NaN
# freq           3600            NaN
# mean            NaN       0.897452
# std             NaN       0.063443
# min             NaN       0.502000
# 25%             NaN       0.868429
# 50%             NaN       0.913667
# 75%             NaN       0.942684
# max             NaN       0.990500
#
#                                                    en_doc  \
# count                                              101807
# unique                                             101807
# top     It went out with a bang. The evening sparkled ...
# freq                                                    1
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                                    sl_doc      en_length  \
# count                                              101807  101807.000000
# unique                                              92544            NaN
# top     Ali se strinjate, da na vaš računalnik namesti...            NaN
# freq                                                   30            NaN
# mean                                                  NaN     428.811084
# std                                                   NaN    1694.062268
# min                                                   NaN      75.000000
# 25%                                                   NaN     119.000000
# 50%                                                   NaN     190.000000
# 75%                                                   NaN     346.000000
# max                                                   NaN   98761.000000
#
#             sl_length    punct_ratio
# count   101807.000000  101807.000000
# unique            NaN            NaN
# top               NaN            NaN
# freq              NaN            NaN
# mean       495.158761       0.092997
# std       2320.090506       0.027555
# min          2.000000       0.015000
# 25%         93.000000       0.074830
# 50%        165.000000       0.089552
# 75%        324.000000       0.106952
# max      94079.000000       0.200000

# %%
# Inspect en_var_doc statistics
print(corpus_df.en_var_doc.value_counts(normalize = True).to_markdown())
# Out:
# |     |   en_var_doc |
# |:----|-------------:|
# | B   |    0.421287  |
# | UNK |    0.351813  |
# | A   |    0.165755  |
# | MIX |    0.0611451 |

# %%
print(corpus_df.en_var_dom.value_counts(normalize = True).to_markdown())
# Out:
# |     |   en_var_dom |
# |:----|-------------:|
# | B   |   0.567122   |
# | MIX |   0.281886   |
# | A   |   0.140992   |
# | UNK |   0.00999931 |

# %%
# Inspect translation direction
print(corpus_df.translation_direction.value_counts(normalize = True).to_markdown())
# Out:
# |         |   translation_direction |
# |:--------|------------------------:|
# | sl-orig |                  0.8893 |
# | en-orig |                  0.1107 |

# %%
print(corpus_df.average_score.describe().to_markdown())
# Out:
# |       |   average_score |
# |:------|----------------:|
# | count |  101807         |
# | mean  |       0.897452  |
# | std   |       0.0634431 |
# | min   |       0.502     |
# | 25%   |       0.868429  |
# | 50%   |       0.913667  |
# | 75%   |       0.942684  |
# | max   |       0.9905    |

# %%
corpus_df.en_length.describe()
# Out:
# count    101807.000000
# mean        428.811084
# std        1694.062268
# min          75.000000
# 25%         119.000000
# 50%         190.000000
# 75%         346.000000
# max       98761.000000
# Name: en_length, dtype: float64

# %%
# Inspect duplicated Slovene texts
pd.set_option('display.max_colwidth', None)
duplicated = corpus_df[corpus_df.sl_doc.duplicated(keep=False)].sort_values("sl_doc")
duplicated[["sl_doc", "en_doc", "average_score"]]

# %%
# Inspect whether this solved any issues with non-textual texts
non_textual_index = [1887229, 798879, 5579561,  150635, 2050301,  472170,  249792, 65284,  477792,  282858, 1738274, 2754062,   84675]

discarded_counter = 0

remaining_index = []

for i in non_textual_index:
	try:
		print(corpus_df.loc[i].en_doc)
		remaining_index.append(i)

	except KeyError:
		print(f"{i} not in final corpus.")
		discarded_counter += 1

print(discarded_counter)
print(remaining_index)
# Out:
# 1887229 not in final corpus.
# 798879 not in final corpus.
# 5579561 not in final corpus.
# Dejan Habicht - Zvočni film / Sound Movie (00:05:22) Subtitle: 12 dolgočasnih pesmi Production: Center in Galerija P74, 2007 The sound of an airplane over a forest. Dejan Habicht - Nevarni vzorci Subtitle: 12 dolgočasnih pesmi Production: Center in Galerija P74, 2006 Dangerous Patterns is an electronic book, which can be printed at home (557KB). Dejan Habicht - die Heißeste Nummer Subtitle: 12 dolgočasnih pesmi Production: Center in Galerija P74, 2004/06 die Heißeste Nummer / The Hottest Number is an e-book that one can print at home. Saša Spačal - 7K: new life form (00:10:13) Production: Saša Spačal, Muzej sodobne umetnosti Metelkova - MSUM+, 2016 The video conceptually reflects on 7K: new life form, an artwork by Saša Spačal.
# 2050301 not in final corpus.
# 472170 not in final corpus.
# 249792 not in final corpus.
# 65284 not in final corpus.
# 477792 not in final corpus.
# 282858 not in final corpus.
# 1738274 not in final corpus.
# Instructions for use of QR Code for FOTO LADO d.o.o. Click here for further information. Instructions for use of QR Code for STROPNIK RADO s.p. Instructions for use of QR Code for STROPNIK RADO s.p. Instructions for use of QR Code for PETER KLINC s.p. Click here for further information. Instructions for use of QR Code for FOTO M DAVORIN FLIS S.P. Instructions for use of QR Code for FOTO M DAVORIN FLIS S.P. Instructions for use of QR Code for FOTO M DAVORIN FLIS S.P. Instructions for use of QR Code for FOTO HOST, Hozyan Štefan, s.p. Instructions for use of QR Code for FOTO HOST, Hozyan Štefan, s.p. Instructions for use of QR Code for FOTO IVKO, KARMEN KOGAL S.P. Instructions for use of QR Code for FOTO KLAVDIJA, Kobal Klavdija, s.p.
# The former village of the Gottschee Germans is situated in a place with a view, near the round hilltop. German word… This former village of the Gottschee Germans is situated in a location to the west of Polom, in a hilly… The former village of the Gottschee Germans is situated right at the edge, in the southeast of a system of… This former village of the Gottschee Germans is situated on the eastern, rather gently sloping, side of the peak of… The former village of the Gottschee Germans is situated in a Carst basin between Kočevski Rog in the north and… This former village of the Gottschee Germans is situated in the middle of the woods near the mountain Rog and… Once a workers’ settlement, Jelendol is situated in a wavy, woodsy world, next to the road between Dolenja Vas and… This former village of the Gottschee Germans is situated in the middle of the woods near the mountain Rog and… Once a workers’ settlement, Jelendol is situated in a wavy, woodsy world, next to the road between Dolenja Vas and… The abandoned village of the Gottschee Germans is situated in the valley of Verderb and Verdreng or the Podleška valley,… The abandoned village of the Gottschee Germans is situated in the valley of Verderb and Verdreng or the Podleška valley,… Nosilec projekta
# 10
# [150635, 2754062, 84675]

# %%
from itertools import islice

def chunk(arr_range, arr_size):
	arr_range = iter(arr_range)
	return iter(lambda: tuple(islice(arr_range, arr_size)), ())

batches_list = list(chunk(corpus_df.en_source[:10], 3))

for i in batches_list:
	print(list(i))
# Out:
# ['http://15.liffe.si/?lang_chg=en', 'http://16.liffe.si/?lang_chg=en', 'http://17.liffe.si/?lang_chg=en']
# ['http://1proti1.mg-lj.si/en/concept/', 'http://2006.fdf.si/?lang_chg=en', 'http://2007-2013.ita-slo.eu/news/contacts/']
# ['http://2007-2013.ita-slo.eu/programme/basic_information/', 'http://2007-2013.ita-slo.eu/programme/erdf_co_funding/', 'http://2007-2013.ita-slo.eu/programme/objectives/']
# ['http://2007-2013.ita-slo.eu/programme/priorities/']
