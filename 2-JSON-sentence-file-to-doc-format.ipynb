# %%
import pandas as pd
import numpy as np
import regex as re
import json

# %% [markdown]
# ## Preparation of document format from sentence format

# %%
# Import json
with open("Macocu-sl-en.json", "r") as file:
	tus_content = json.load(file)

# %%
# Convert data to a dataframe

corpus_df = pd.DataFrame(tus_content)

corpus_df.head()

# %%
# Analyze distribution
corpus_df.describe(include="all")
# Out:
#         score_bicleaner_ai biroamer_entities translation_direction  \
# count         3.176311e+06           3176311               3176311
# unique                 NaN                 2                     2
# top                    NaN                No               sl-orig
# freq                   NaN           2897662               2812317
# mean          8.809970e-01               NaN                   NaN
# std           1.299268e-01               NaN                   NaN
# min           5.000000e-01               NaN                   NaN
# 25%           8.250000e-01               NaN                   NaN
# 50%           9.440000e-01               NaN                   NaN
# 75%           9.760000e-01               NaN                   NaN
# max           9.940000e-01               NaN                   NaN
#
#                                                 en_source en_par_id  \
# count                                             3176311   3176311
# unique                                             285892     93755
# top     http://nl.ijs.si/ME/Vault/V3/htm/mte-cesdoc-mt...     p26s0
# freq                                                 5112     36423
# mean                                                  NaN       NaN
# std                                                   NaN       NaN
# min                                                   NaN       NaN
# 25%                                                   NaN       NaN
# 50%                                                   NaN       NaN
# 75%                                                   NaN       NaN
# max                                                   NaN       NaN
#
#                                                    en_par en_var_doc  \
# count                                             3176311    3176311
# unique                                            2379921          4
# top     You should consider whether you understand how...          B
# freq                                                  745    1640246
# mean                                                  NaN        NaN
# std                                                   NaN        NaN
# min                                                   NaN        NaN
# 25%                                                   NaN        NaN
# 50%                                                   NaN        NaN
# 75%                                                   NaN        NaN
# max                                                   NaN        NaN
#
#        en_var_dom                                          sl_source  \
# count     3176311                                            3176311
# unique          4                                             456366
# top             B  http://nl.ijs.si/ME/Vault/V3/htm/mte-cesdoc-mt...
# freq      1967189                                               4294
# mean          NaN                                                NaN
# std           NaN                                                NaN
# min           NaN                                                NaN
# 25%           NaN                                                NaN
# 50%           NaN                                                NaN
# 75%           NaN                                                NaN
# max           NaN                                                NaN
#
#        sl_par_id                                             sl_par
# count    3176311                                            3176311
# unique     86818                                            2542560
# top        p26s0  Izdelana je iz prijetne mešanice naravnega in ...
# freq       33594                                                207
# mean         NaN                                                NaN
# std          NaN                                                NaN
# min          NaN                                                NaN
# 25%          NaN                                                NaN
# 50%          NaN                                                NaN
# 75%          NaN                                                NaN
# max          NaN                                                NaN

# %% [markdown]
# #### Bi-Cleaner Scores on sentence level
#
# As we can see from the column on score_bicleaner_ai, it seems that there are no sentences with score lower than 0.5 - they must have been already filtered out? (?). We can also see, that was majority of sentences were originally written in Slovene (based on translation_direction), and that 700 English sentences and 200 Slovene sentences are repeated which could indicate some errors.

# %%
# Sort by english url and then by en_par_id to order the paragraphs into texts
corpus_df = corpus_df.sort_values(by = ["en_source", "en_par_id"])

corpus_df

# %%
# Add information about domains
domain_re=re.compile(r'^https?://(?:www\.)?(.+?)[/$]')

en_domain_list = [domain_re.search(i).group(1) for i in corpus_df.en_source.to_list()]

en_domain_list[:3]
# Out:
# ['15.liffe.si', '15.liffe.si', '15.liffe.si']

# %%
corpus_df["en_domain"] = en_domain_list

corpus_df.head(2)

# %%
# Repeat with Slovene domain
sl_domain_list = [domain_re.search(i).group(1) for i in corpus_df.sl_source.to_list()]
corpus_df["sl_domain"] = sl_domain_list

corpus_df.head(2)

# %%
# Add information whether the domains are the same
corpus_df["same_domains"] = np.where(corpus_df["en_domain"] == corpus_df["sl_domain"], "yes", 'no')

# Add column for domains that are different
corpus_df["different_domains"] = corpus_df["en_domain"] + " " + corpus_df["sl_domain"]

corpus_df.head(2)

# %%
corpus_df["same_domains"].value_counts()
# Out:
# yes    2347120
# no      829191
# Name: same_domains, dtype: int64

# %%
# Analyze instances from different domains
corpus_df[corpus_df["same_domains"] != "yes"]["different_domains"] .value_counts()
# Out:
# eur-lex.europa.eu uradni-list.si                 21956
# eur-lex.europa.eu europarl.europa.eu             16475
# europarl.europa.eu eur-lex.europa.eu              8431
# croatiabeachacc.com privatapartmajihrvaska.si     6907
# predsednik.si up-rs.si                            6439
#                                                  ...
# eesc.europa.eu okolje.si                             1
# eesc.europa.eu nova-gorica.si                        1
# eesc.europa.eu plastika-lvp.si                       1
# eesc.europa.eu e-uprava.gov.si                       1
# savacommission.org posavskiobzornik.si               1
# Name: different_domains, Length: 118892, dtype: int64

# %%
# Calculate average bicleaner ai score based on the en_source
corpus_df["average_score"] = corpus_df["score_bicleaner_ai"].groupby(corpus_df['en_source']).transform('mean')

corpus_df.head(2)

# %%
# Add to each instance from the same en_source joint text from all sentences
corpus_df["en_doc"] = corpus_df["en_par"].groupby(corpus_df['en_source']).transform(' '.join)

corpus_df.head(2)

# %%
# Repeat with the Slovene text
corpus_df["sl_doc"] = corpus_df["sl_par"].groupby(corpus_df['sl_source']).transform(' '.join)
corpus_df.head(2)

# %%
# Keep only one example of each text
corpus_df = corpus_df.drop_duplicates("en_doc")

corpus_df.shape
# Out:
# (281475, 18)

# %%
corpus_df.describe(include="all")
# Out:
#         score_bicleaner_ai biroamer_entities translation_direction  \
# count        281475.000000            281475                281475
# unique                 NaN                 2                     2
# top                    NaN                No               sl-orig
# freq                   NaN            245570                241480
# mean              0.841095               NaN                   NaN
# std               0.143561               NaN                   NaN
# min               0.500000               NaN                   NaN
# 25%               0.740000               NaN                   NaN
# 50%               0.898000               NaN                   NaN
# 75%               0.963000               NaN                   NaN
# max               0.993000               NaN                   NaN
#
#                               en_source en_par_id  \
# count                            281475    281475
# unique                           281475     15104
# top     http://15.liffe.si/?lang_chg=en     p10s0
# freq                                  1     12036
# mean                                NaN       NaN
# std                                 NaN       NaN
# min                                 NaN       NaN
# 25%                                 NaN       NaN
# 50%                                 NaN       NaN
# 75%                                 NaN       NaN
# max                                 NaN       NaN
#
#                                                    en_par en_var_doc  \
# count                                              281475     281475
# unique                                             268451          4
# top     You should consider whether you understand how...        UNK
# freq                                                  181     155208
# mean                                                  NaN        NaN
# std                                                   NaN        NaN
# min                                                   NaN        NaN
# 25%                                                   NaN        NaN
# 50%                                                   NaN        NaN
# 75%                                                   NaN        NaN
# max                                                   NaN        NaN
#
#        en_var_dom                                     sl_source sl_par_id  \
# count      281475                                        281475    281475
# unique          4                                        232628     13766
# top             B  https://www.realitica.com/en/listing/2447504     p26s0
# freq       129844                                            13      9302
# mean          NaN                                           NaN       NaN
# std           NaN                                           NaN       NaN
# min           NaN                                           NaN       NaN
# 25%           NaN                                           NaN       NaN
# 50%           NaN                                           NaN       NaN
# 75%           NaN                                           NaN       NaN
# max           NaN                                           NaN       NaN
#
#                                                    sl_par        en_domain  \
# count                                              281475           281475
# unique                                             250662            11959
# top     Če želite izvedeti več, lahko preberete našo p...  rumenestrani.si
# freq                                                  101            17392
# mean                                                  NaN              NaN
# std                                                   NaN              NaN
# min                                                   NaN              NaN
# 25%                                                   NaN              NaN
# 50%                                                   NaN              NaN
# 75%                                                   NaN              NaN
# max                                                   NaN              NaN
#
#               sl_domain same_domains                different_domains  \
# count            281475       281475                           281475
# unique            17279            2                            52579
# top     rumenestrani.si          yes  rumenestrani.si rumenestrani.si
# freq              16582       191600                            16494
# mean                NaN          NaN                              NaN
# std                 NaN          NaN                              NaN
# min                 NaN          NaN                              NaN
# 25%                 NaN          NaN                              NaN
# 50%                 NaN          NaN                              NaN
# 75%                 NaN          NaN                              NaN
# max                 NaN          NaN                              NaN
#
#         average_score                                             en_doc  \
# count   281475.000000                                             281475
# unique            NaN                                             281475
# top               NaN  It went out with a bang. The evening sparkled ...
# freq              NaN                                                  1
# mean         0.846546                                                NaN
# std          0.109657                                                NaN
# min          0.500000                                                NaN
# 25%          0.785750                                                NaN
# 50%          0.876000                                                NaN
# 75%          0.931750                                                NaN
# max          0.992000                                                NaN
#
#                                                    sl_doc
# count                                              281475
# unique                                             230097
# top     Če želite izvedeti več, lahko preberete našo p...
# freq                                                   53
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN

# %%
corpus_df.head()

# %%
# Add information about length
corpus_df["en_length"] = corpus_df.en_doc.str.split().str.len()

corpus_df.head(3)

# %%
corpus_df.en_length.describe()
# Out:
# count    281475.000000
# mean        258.774364
# std        1384.547486
# min           1.000000
# 25%          29.000000
# 50%          79.000000
# 75%         207.000000
# max      106893.000000
# Name: en_length, dtype: float64

# %%
# Add information about Slovene length
corpus_df["sl_length"] = corpus_df.sl_doc.str.split().str.len()

corpus_df.head(3)

# %%
# Analyze Slovene length
corpus_df.sl_length.describe()
# Out:
# count    141066.000000
# mean        453.143635
# std        2290.479800
# min           2.000000
# 25%          78.000000
# 50%         148.000000
# 75%         307.000000
# max       98530.000000
# Name: sl_length, dtype: float64

# %%
# Discard instances that have length less than the median - less than 79
corpus_df = corpus_df[corpus_df["en_length"] > 78]

corpus_df.shape
# Out:
# (141066, 19)

# %% [markdown]
# After discarding texts that have length less than the median - less than 79 words, the Slovene-English corpus consists of 141066 aligned texts.

# %%
corpus_df.columns
# Out:
# Index(['score_bicleaner_ai', 'biroamer_entities', 'translation_direction',
#        'en_source', 'en_par_id', 'en_par', 'en_var_doc', 'en_var_dom',
#        'sl_source', 'sl_par_id', 'sl_par', 'en_domain', 'sl_domain',
#        'same_domains', 'different_domains', 'average_score', 'en_doc',
#        'sl_doc', 'en_length'],
#       dtype='object')

# %%
# Discard irrelevant columns
corpus_df = corpus_df.drop(columns = ['score_bicleaner_ai', 'en_par_id', 'en_par', 'sl_par_id', 'sl_par'])
corpus_df.head()
# Out:
#         biroamer_entities translation_direction  \
# 2584979                No               sl-orig
# 1212933                No               sl-orig
# 598330                Yes               sl-orig
# 2796982                No               sl-orig
# 642105                Yes               sl-orig
#
#                                    en_source en_var_doc en_var_dom  \
# 2584979      http://15.liffe.si/?lang_chg=en          B          B
# 1212933      http://16.liffe.si/?lang_chg=en          B          B
# 598330       http://17.liffe.si/?lang_chg=en          B          B
# 2796982  http://1proti1.mg-lj.si/en/concept/        UNK        UNK
# 642105       http://2006.fdf.si/?lang_chg=en          B          B
#
#                                                  sl_source         en_domain  \
# 2584979                    http://15.liffe.si/?lang_chg=sl       15.liffe.si
# 1212933       http://16.liffe.si/index.php?menu_item=domov       16.liffe.si
# 598330                     http://17.liffe.si/?lang_chg=sl       17.liffe.si
# 2796982  http://www.mg-lj.si/si/razstave/98/vmesna-postaja  1proti1.mg-lj.si
# 642105   http://2006.fdf.si/?menu_item=podatki&amp;menu...       2006.fdf.si
#
#            sl_domain same_domains          different_domains  average_score  \
# 2584979  15.liffe.si          yes    15.liffe.si 15.liffe.si       0.936808
# 1212933  16.liffe.si          yes    16.liffe.si 16.liffe.si       0.900000
# 598330   17.liffe.si          yes    17.liffe.si 17.liffe.si       0.957875
# 2796982     mg-lj.si           no  1proti1.mg-lj.si mg-lj.si       0.945633
# 642105   2006.fdf.si          yes    2006.fdf.si 2006.fdf.si       0.941667
#
#                                                     en_doc  \
# 2584979  It went out with a bang. The evening sparkled ...
# 1212933  Some days ago the organisers of the 17th Liffe...
# 598330   17th LIFFe was brought to an end with the best...
# 2796982  Concept Not interested in showcasing art, 1:1 ...
# 642105   The 8th International Documentary Film Festiva...
#
#                                                     sl_doc  en_length
# 2584979  Končalo se je razburljivo in z razkošjem. Veče...        601
# 1212933  Pred dnevi smo se iz 59. mednarodnega filmskeg...        293
# 598330   S podelitvijo nagrad in predvajanjem Režiserja...        445
# 2796982  VMESNO POSTAJO 1:1 organiziramo v koprodukciji...        827
# 642105   S slovenskim filmom Poročno potovanje se je ko...        423

# %%
# Inspect corpus information
corpus_df.describe(include="all")
# Out:
#        biroamer_entities translation_direction  \
# count             141066                141066
# unique                 2                     2
# top                   No               sl-orig
# freq              122869                124561
# mean                 NaN                   NaN
# std                  NaN                   NaN
# min                  NaN                   NaN
# 25%                  NaN                   NaN
# 50%                  NaN                   NaN
# 75%                  NaN                   NaN
# max                  NaN                   NaN
#
#                               en_source en_var_doc en_var_dom  \
# count                            141066     141066     141066
# unique                           141066          4          4
# top     http://15.liffe.si/?lang_chg=en        UNK          B
# freq                                  1      55840      77117
# mean                                NaN        NaN        NaN
# std                                 NaN        NaN        NaN
# min                                 NaN        NaN        NaN
# 25%                                 NaN        NaN        NaN
# 50%                                 NaN        NaN        NaN
# 75%                                 NaN        NaN        NaN
# max                                 NaN        NaN        NaN
#
#                                                 sl_source    en_domain  \
# count                                              141066       141066
# unique                                             126398         8507
# top     https://www.sofascore.com/sl/ekipa/nogomet/vik...  oblacila.si
# freq                                                    9         3982
# mean                                                  NaN          NaN
# std                                                   NaN          NaN
# min                                                   NaN          NaN
# 25%                                                   NaN          NaN
# 50%                                                   NaN          NaN
# 75%                                                   NaN          NaN
# max                                                   NaN          NaN
#
#           sl_domain same_domains        different_domains  average_score  \
# count        141066       141066                   141066  141066.000000
# unique        11529            2                    25040            NaN
# top     oblacila.si          yes  oblacila.si oblacila.si            NaN
# freq           3952       104853                     3949            NaN
# mean            NaN          NaN                      NaN       0.875767
# std             NaN          NaN                      NaN       0.074288
# min             NaN          NaN                      NaN       0.502000
# 25%             NaN          NaN                      NaN       0.833667
# 50%             NaN          NaN                      NaN       0.894077
# 75%             NaN          NaN                      NaN       0.932000
# max             NaN          NaN                      NaN       0.990500
#
#                                                    en_doc  \
# count                                              141066
# unique                                             141066
# top     It went out with a bang. The evening sparkled ...
# freq                                                    1
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                                    sl_doc      en_length
# count                                              141066  141066.000000
# unique                                             126147            NaN
# top     Ali se strinjate, da na vaš računalnik namesti...            NaN
# freq                                                   23            NaN
# mean                                                  NaN     483.234918
# std                                                   NaN    1929.667052
# min                                                   NaN      79.000000
# 25%                                                   NaN     126.000000
# 50%                                                   NaN     207.000000
# 75%                                                   NaN     392.000000
# max                                                   NaN  106893.000000

# %%
# Inspect en_var_doc statistics
print(corpus_df.en_var_doc.value_counts(normalize = True).to_markdown())
# Out:
# |     |   en_var_doc |
# |:----|-------------:|
# | B   |    0.390137  |
# | UNK |    0.389793  |
# | A   |    0.162199  |
# | MIX |    0.0578715 |

# %%
print(corpus_df.en_var_dom.value_counts(normalize = True).to_markdown())
# Out:
# |     |   en_var_dom |
# |:----|-------------:|
# | B   |   0.539765   |
# | MIX |   0.284293   |
# | A   |   0.16629    |
# | UNK |   0.00965161 |

# %%
# Inspect translation direction
print(corpus_df.translation_direction.value_counts(normalize = True).to_markdown())
# Out:
# |         |   translation_direction |
# |:--------|------------------------:|
# | sl-orig |                0.886241 |
# | en-orig |                0.113759 |

# %%
print(corpus_df.average_score.describe().to_markdown())
# Out:
# |       |   average_score |
# |:------|----------------:|
# | count |  104853         |
# | mean  |       0.886736  |
# | std   |       0.0682533 |
# | min   |       0.502     |
# | 25%   |       0.8519    |
# | 50%   |       0.904     |
# | 75%   |       0.93675   |
# | max   |       0.9905    |

# %% [markdown]
# #### Main information on the corpus
#
# As we can see, almost all of the documents were originally written in Slovene (88%). Most of them are identified as "UNK" (40%), followed by British (39%), and much less American texts, by English variety detection on document level. On the domain level, most of them (55%) were identified to be British. Most of the texts have quality higher than 0.90 based on the bicleaner score. There are 23 Slovene duplicated texts.

# %%
# Analyze instances from different domains
corpus_df["same_domains"].value_counts()
# Out:
# yes    104853
# no      36213
# Name: same_domains, dtype: int64

# %%
corpus_df[corpus_df["same_domains"] != "yes"]["different_domains"] .value_counts()
# Out:
# eugo.gov.si spot.gov.si                                           366
# plus500.com plus500.si                                            283
# croatiabeachacc.com privatapartmajihrvaska.si                     281
# hajdi.net hajdi.si                                                258
# bsi.si bsi.azurewebsites.net                                      257
#                                                                  ...
# etnamaar.com casmatino.si                                           1
# etnologija.etnoinfolab.org anglistika.ff.uni-lj.si                  1
# etnologija.etnoinfolab.org ffa.uni-lj.si                            1
# etnologija.etnoinfolab.org pedagogika-andragogika.ff.uni-lj.si      1
# 塞尔维亚.realigro.asia oglasi.si                                        1
# Name: different_domains, Length: 19060, dtype: int64

# %%
len(corpus_df.different_domains.unique())
# Out:
# 25040

# %%
# Inspect duplicated Slovene texts
pd.set_option('display.max_colwidth', None)
duplicated = corpus_df[corpus_df.sl_doc.duplicated(keep=False)].sort_values("sl_doc")
duplicated[["sl_doc", "en_doc", "average_score"]]

# %%
# Inspect a random sample
pd.set_option('display.max_colwidth', 300)
corpus_df.sample(n=20)
# Out:
#         biroamer_entities translation_direction  \
# 1548798               Yes               sl-orig
# 84755                 Yes               sl-orig
# 2562108                No               sl-orig
# 348403                 No               sl-orig
# 2031466                No               sl-orig
# 609292                 No               sl-orig
# 1805773                No               sl-orig
# 1737177                No               sl-orig
# 1993535                No               sl-orig
# 930061                 No               sl-orig
# 2223005                No               sl-orig
# 71124                  No               sl-orig
# 245429                Yes               en-orig
# 806658                 No               sl-orig
# 1126067                No               sl-orig
# 2598465                No               sl-orig
# 577848                 No               sl-orig
# 739258                 No               sl-orig
# 1545007                No               sl-orig
# 1668855                No               sl-orig
#
#                                                                                                                         en_source  \
# 1548798                                        https://www.bled.si/en/what-to-see-do/cuisine/2019100208524126/educational-beehive
# 84755                                                                                         http://pefprints.pef.uni-lj.si/469/
# 2562108                                                               http://newsletter.etwinning.net/en/pub/2013/etnl_062013.htm
# 348403                                  https://oblacila.si/under-armour-under-armour-tricko-performance-polo-2.0-blu__7wyPxjjEtG
# 2031466                                                             http://eugo.gov.si/en/activities/activity/14091/showActivity/
# 609292                                                                    https://www.pokerharder.com/en-gb/learn-poker/variants/
# 1805773                                                      http://visitcerkno.si/en/boulders-on-the-crni-vrh-hill-above-cerkno/
# 1737177                                                                                    https://www.nuk.uni-lj.si/eng/node/489
# 1993535                                      https://eur-lex.europa.eu/legal-content/EN/TXT/HTML/?uri=LEGISSUM:l28056&amp;from=HR
# 930061                       https://www.agencia.si/en/print/243524-oddaja-poslovni-prostor-skladisce-obalno-kraska-sezana-storje
# 2223005             http://arhivffweb2020.ff.uni-lj.si/an/study/departments/department_comparative_literature_and_literary_theory
# 71124                           https://www.mirovni-institut.si/en/projects/informal-reproductive-work-trends-in-slovenia-and-eu/
# 245429                                                 http://ricinus2.mf.uni-lj.si/bs/neva.exe?name=bs_cx&amp;e=%22Vancomycin%22
# 806658                                                                        https://www.spiderfestival.com/tandem-kresnicka-eng
# 1126067                                                                           https://arhiv.akos-rs.si/railway-service-market
# 2598465                                                                         https://www.bekament.com/en/proizvodi/bk-podloga/
# 577848                                                              https://www.consilium.europa.eu/en/policies/eu-recovery-plan/
# 739258                                                   http://www.cer-slo.si/1green-breakfast---greentech-forum-14-02-2019.html
# 1545007                                                                                         https://roglab.si/en/news/item-0/
# 1668855  http://www.sayhellototheworld.eu/en/gallery/year-2016-2017/first-call/first-video-call-warsaw-slovenia-vilnius-lithuania
#
#         en_var_doc en_var_dom  \
# 1548798          B          B
# 84755            A          B
# 2562108          B          B
# 348403           A        MIX
# 2031466          B          B
# 609292         MIX        MIX
# 1805773          A          A
# 1737177        UNK          B
# 1993535          B          B
# 930061         UNK          A
# 2223005          B          B
# 71124            B          B
# 245429         MIX        MIX
# 806658         UNK          B
# 1126067          B        MIX
# 2598465          A          A
# 577848           B          B
# 739258           B        MIX
# 1545007          A          B
# 1668855        UNK          B
#
#                                                                                                                                 sl_source  \
# 1548798                                               https://www.bled.si/sl/kaj-videti-poceti/kulinarika/2019100208285395/ucni-cebelnjak
# 84755                                                                                                 http://pefprints.pef.uni-lj.si/450/
# 2562108                                                                       http://newsletter.etwinning.net/sl/pub/2013/etnl_062013.htm
# 348403                                                                   https://oblacila.si/siksilk-siksilk-majica-mornarska__El84a70qEH
# 2031466                                                       https://spot.gov.si/sl/dejavnosti-in-poklici/dejavnosti-skd/obdelava-semen/
# 609292                                                                                         https://stave-online.com/video-poker-igre/
# 1805773                                                                               http://visitcerkno.si/balvani-crni-vrh-nad-cerknim/
# 1737177                                                                       https://www.nuk.uni-lj.si/nuk/organizacija/zbirka-rokopisov
# 1993535                                    https://www.mrezaprostor.si/aktualno/pripomocki-za-sodelovanje-javnosti-pri-urejanju-prostora/
# 930061                      https://www.gbnepremicnine.si/nepremicnine/stanovanje.v1/trisobno.t7/Ljubljana.r1/_850eur.q/_900eur.w/p1.html
# 2223005                                                                                     http://arhivffweb2020.ff.uni-lj.si/primknjiz/
# 71124                                    https://www.mirovni-institut.si/projekti/neformalno-reproduktivno-delo-trendi-v-sloveniji-in-eu/
# 245429                                                 http://ricinus2.mf.uni-lj.si/BS/neva.exe?name=bs_cx&amp;e=%22Intenzivne%20enote%22
# 806658                                                                                 https://www.spiderfestival.com/tandem-kresnika-slo
# 1126067                                                                                 https://arhiv.akos-rs.si/trg-zelezniskih-storitev
# 2598465                                                                                 https://www.bekament.com/sl/proizvodi/bk-podloga/
# 577848             https://www.nas-stik.si/1/Novice/novice/tabid/87/ID/8062/Mehanizem-za-okrevanje-in-odpornost-oddaljen-le-se-korak.aspx
# 739258                                                         http://cer-slo.si/greentech-forum-bled-i-12-september-2018-12-09-2018.html
# 1545007                                                                 https://roglab.si/sl/novice/avatarke-virtualni-in-realni-prostori
# 1668855  http://www.sayhellototheworld.eu/hr/galerija/godina-2017-2018/drugo-javljanje/drugo-javljanje-jastrebarsko-hrvaska-vilnius-litva
#
#                            en_domain                    sl_domain  \
# 1548798                      bled.si                      bled.si
# 84755        pefprints.pef.uni-lj.si      pefprints.pef.uni-lj.si
# 2562108     newsletter.etwinning.net     newsletter.etwinning.net
# 348403                   oblacila.si                  oblacila.si
# 2031466                  eugo.gov.si                  spot.gov.si
# 609292               pokerharder.com             stave-online.com
# 1805773               visitcerkno.si               visitcerkno.si
# 1737177                nuk.uni-lj.si                nuk.uni-lj.si
# 1993535            eur-lex.europa.eu              mrezaprostor.si
# 930061                    agencia.si            gbnepremicnine.si
# 2223005  arhivffweb2020.ff.uni-lj.si  arhivffweb2020.ff.uni-lj.si
# 71124            mirovni-institut.si          mirovni-institut.si
# 245429         ricinus2.mf.uni-lj.si        ricinus2.mf.uni-lj.si
# 806658            spiderfestival.com           spiderfestival.com
# 1126067             arhiv.akos-rs.si             arhiv.akos-rs.si
# 2598465                 bekament.com                 bekament.com
# 577848           consilium.europa.eu                  nas-stik.si
# 739258                    cer-slo.si                   cer-slo.si
# 1545007                    roglab.si                    roglab.si
# 1668855        sayhellototheworld.eu        sayhellototheworld.eu
#
#         same_domains                                        different_domains  \
# 1548798          yes                                          bled.si bled.si
# 84755            yes          pefprints.pef.uni-lj.si pefprints.pef.uni-lj.si
# 2562108          yes        newsletter.etwinning.net newsletter.etwinning.net
# 348403           yes                                  oblacila.si oblacila.si
# 2031466           no                                  eugo.gov.si spot.gov.si
# 609292            no                         pokerharder.com stave-online.com
# 1805773          yes                            visitcerkno.si visitcerkno.si
# 1737177          yes                              nuk.uni-lj.si nuk.uni-lj.si
# 1993535           no                        eur-lex.europa.eu mrezaprostor.si
# 930061            no                             agencia.si gbnepremicnine.si
# 2223005          yes  arhivffweb2020.ff.uni-lj.si arhivffweb2020.ff.uni-lj.si
# 71124            yes                  mirovni-institut.si mirovni-institut.si
# 245429           yes              ricinus2.mf.uni-lj.si ricinus2.mf.uni-lj.si
# 806658           yes                    spiderfestival.com spiderfestival.com
# 1126067          yes                        arhiv.akos-rs.si arhiv.akos-rs.si
# 2598465          yes                                bekament.com bekament.com
# 577848            no                          consilium.europa.eu nas-stik.si
# 739258           yes                                    cer-slo.si cer-slo.si
# 1545007          yes                                      roglab.si roglab.si
# 1668855          yes              sayhellototheworld.eu sayhellototheworld.eu
#
#          average_score  \
# 1548798       0.902182
# 84755         0.810500
# 2562108       0.958364
# 348403        0.824923
# 2031466       0.947000
# 609292        0.733500
# 1805773       0.874625
# 1737177       0.830000
# 1993535       0.758364
# 930061        0.835500
# 2223005       0.957750
# 71124         0.925000
# 245429        0.806421
# 806658        0.886300
# 1126067       0.969000
# 2598465       0.947000
# 577848        0.768875
# 739258        0.887143
# 1545007       0.886250
# 1668855       0.862800
#
#                                                                                                                                                                                                                                                                                                               en_doc  \
# 1548798  Danijela and Blaž Ambrožič, who have been in the beekeeping tourism business since 2011, made it possible to observe the life of the Grey bee of Carniola ("kranjska sivka") in the beehive from a safe distance in their village of Selo pri Bledu. Around 30 bee colonies live in the educational beeh...
# 84755    This paper presents the results, gathered in Slovenian kindergartens participating in the project "Professional training of professional staff to implement specific elements of teaching the principles of Reggio Emilia concept in pre-school." This paper presents the results, gathered in Slovenian...
# 2562108  After a careful analysis of pedagogical methods used by each of the partners we want to understand children's needs and difficulties in mathematics, make some special activity and develop new teaching practices. Many eTwinning countries have seen the development of Ambassador networks – but what...
# 348403   The shirt then also features short sleeves for a classic look and is produced in a lightweight construction with Climalite technology that quickly wicks sweats away from your body. The shirt then also features short sleeves for a classic look and is produced in a lightweight construction with Cl...
# 2031466  This subclass includes activities related to the improvement of the quality of seed units by means of cleaning, removal of unwanted impurities, damaged or small seeds as well as by drying seeds for storage. The production, preparation for the market, import and/or marketing of agricultural seeds...
# 609292   Players receive whole poker hands and then have the option to swap any of their cards for new ones from the rest of the deck, this action is why the games are known as ‘draw’ poker. Poker Game Variants Stud poker is not classified as a single set game, like Texas Hold’em or Omaha but rather a gr...
# 1805773  There are many different types of sport climbing and one of them is boulder climbing – climbing on boulders and lower parts of walls. The boulders on the Črni Vrh hill above Cerkno lie in a mixed forest at the altitude of 1,000 m, which is why summer is the best time for a visit, but it is possi...
# 1737177  They include 122 manuscript items, mainly codices and individual fragments of medieval manuscripts. The largest and most comprehensive is the collection of Latin manuscripts from the 9th to the end of the 15th century, which contains 91 items. Besides some bound volumes of manuscripts from the p...
# 1993535  to enable public officials and authorities to help and advise the public on access to information, participation in decision-making and access to justice; to enable public officials and authorities to help and advise the public on access to information, participation in decision-making and acces...
# 930061   Costs are not included in the rent. Rental conditions: monthly rent + income tax deduction + security deposit two rents, as a condition for signing the rental agreement, the lessee has to pay to the real estate agency the following costs: drafting of the rental agreement, preparation of hand ove...
# 2223005  Department of Comparative Literature and Literary Theory The beginnings of the Department of Comparative Literature and Literary Theory reach back to 1925, when the Department of Comparative Literature was established at the Faculty of Arts of the University of Ljubljana. Additionally, it also r...
# 71124    Informal Reproductive Work: Trends in Slovenia and EU Domestic work has a long history in the past and today it is at the crossroad of important themes for the European Union, such as informal work, unemployment, ageing of population, (feminisation of) migration, global and class inequalities, c...
# 245429   Godič-Torkar Karmen Prisotnost bakterije Bacillus cereus v bolniškem oddelku in kužninah, tvorba enterotoksinov ter njena občutljivost za antibiotike [The presence of the bacterium Bacillus cereus in the clinical department and in the infectious samples, its enterotoxin production and susceptibi...
# 806658   # who's afraid of mary jane # mary jane feels # mary jane cares not for the limits of possible Tatiana Kocmur, visual artist, and Liza Šimenc, dancer and choreographer, are back, which basically means that Mary Jane is back – again, never the same. Mary Jane * Proteus (v)anguinu might be best de...
# 1126067  Railway Service Market The Agency’s task in the railway field is to monitor competition in the railway services market in both passenger and freight transport. The Agency’s task in the railway field is to monitor competition in the railway services market in both passenger and freight transport....
# 2598465  It is used as a primer before the application of the skimming compound and in the preparation of gypsum cardboards, cement-fiber boards and mineral surfaces for further processing. Before use, BK-Podloga must be diluted with water in ratio BK-Podloga: water = 1: 9. The same dilution ratio is als...
# 577848   The adoption of Council implementing decisions on the approval of the plans permits the member states to sign grant and loan agreements that will allow for up to 13% pre-financing. EU economic and finance ministers adopted the first batch of Council implementing decisions on the approval of nati...
# 739258   Sc., Board Member Petrol d.d. and President of the Board CER In the name of the guest of the round table Violeta Bulc, M. Presentation of good practice – impact of green innovations on economy and local communities Comprehensive solutions of energy supply and mobility for cities, presentation of...
# 1545007  Female Avatars: Virtual and Real Spaces The ČIPke Initiative, RogLab and Rampa Lab prepared a workshop called Female Avatars – Virtual and Real Spaces under the mentorship of inter-media artist Tank Thunderbird. The participants learned to modulate objects and animation using the open-code progr...
# 1668855  First call First video call - Warsaw (Poland) &amp; Vilnius (Lithuania) When learning about the first topic - This is me children carry out a number of interesting activities and also enjoy networking and meeting new friends. First video call - Warsaw (Poland) &amp; Vilnius (Lithuania) When lear...
#
#                                                                                                                                                                                                                                                                                                               sl_doc  \
# 1548798  Učni čebelnjak Da je življenje kranjske sivke v čebelnjaku mogoče opazovati na varnem mestu, sta na Selu pri Bledu poskrbela Danijela in Blaž Ambrožič, ki se s čebelarskim turizmom ukvarjata od leta 2011. V učnem čebelnjaku živi okoli 30 čebeljih družin, čebelnjak pa ima ročno poslikane panjske ...
# 84755                                V raziskavi so sodelovali vzgojitelji prvega kroga izobraževanja »Profesionalno usposabljanje strokovnih delavcev za izvajanje elementov posebnih pedagoških načel koncepta Reggio Emilia na področju predšolske vzgoje v letih 2008– 2013« na Pedagoški fakulteti v Ljubljani.
# 2562108  Po analizi pedagoških metod vseh partnerjev, bomo vzeli pod drobnogled potrebe učencev in njihove težave pri učenju matematike, pričeli bomo s posebnimi aktivnostmi in razvili nove učne prakse. Mreža ambasadorjev eTwinning je vzpostavljena v večini držav, ki sodelujejo v akciji. Kdo pa pravzapra...
# 348403   Obdelava Microban® učinkovito preprečuje neprijeten vonj. Majica je kot prvi sloj namenjena različnim športnim aktivnostim v hladnejšem vremenu, še posebej dobro pa se izkaže pri aktivnostih, kjer se izdatno potimo. Izdelana je iz mehkega mrežastega materiala, ki po zaslugi tehnologije Dri-FIT o...
# 2031466                                                                                            V ta podrazred spadajo dejavnosti v zvezi z izboljševanjem kakovosti semenskega materiala s čiščenjem, odstranjevanjem neželenih primesi, poškodovanih ali premajhnih semen ter s sušenjem semen za skladiščenje.
# 609292   Če sta tudi po zadnjem krogu stav vsaj dva igralca še vedno v igri, morata oba na koncu razkriti karte. Če nimate nobene kombinacije, zmaga igralec z najvišjo karto. Če sta tudi po zadnjem krogu stav vsaj dva igralca še vedno v igri, morata oba na koncu razkriti karte. Čeprav velja Texas Hold’em...
# 1805773  Obstaja več različnih zvrsti športnega plezanja, eno izmed njih je balvansko plezanje – plezanje na balvanih in spodnjih delih sten. Balvani v Črnem vrhu nad Cerknim ležijo v mešanem gozdu na nadmorski višini 1.000 m, zato je poletje najprimernejši čas za obisk. Možno je plezanje preko celega le...
# 1737177  Najobsežnejša je zbirka latinskih rokopisov od 9. pa do konca 15. stoletja, izredno pomembni so tudi srednjeveški rokopisi iz zbirk slavista Jerneja Kopitarja ter barona Žige Zoisa, napisani v cirilici in glagolici. Fond novoveških rokopisov sestavljajo poleg vezanih rokopisov iz obdobja humaniz...
# 1993535                                                                                                                              Konvencija o dostopu do informacij, udeležbi javnosti pri odločanju in dostopu do pravnega varstva v okoljskih zadevah (Aarhuška konvencija) se sicer nanaša na varstvo okolja.
# 930061                                                                                                                                                                                                                                                                                       Stroški niso vključeni.
# 2223005  FF izobražuje študente in ustvarja vrhunske izobražence z odprtim in kritičnim mišljenjem na področju humanistike in družboslovja ter izobraževanja učiteljev s teh področij. Oddelek za primerjalno književnost in literarno teorijo Začetki Oddelka za primerjalno književnost in literarno teorijo se...
# 71124    Neformalno reproduktivno delo: trendi v Sloveniji in EU Reproduktivno delo ima dolgo tradicijo in številne variacije. Danes za Evropsko Unijo predstavlja stičišče pomembnih tem kot so neformalno delo, brezposelnost, staranje prebivalstva, (feminizacijo) migracij, globalne in razredne neenakosti,...
# 245429   Tekauc-Golob Andreja Nedonošenčki z nizko porodno težo (&lt;1500 g) in dojenje [VLBW infants and breastfeeding] 2013 ► Živko Iris Razvijanje delovne kariere izvajalcev zdravstvene nege v intenzivnih enotah Univerzitetnega kliničnega centra Maribor [Developing a professional career of health care...
# 806658   # kdo se boji mary jane # mary jane čuti # mary jane ni mar za meje mogočega Vizualna umetnica Tatiana Kocmur in plesalka ter koreografinja Liza Šimenc se vračata, kar pomeni, da se vrača tudi Mary Jane – spet, nikdar enako. Mary Jane * Proteus (v)anguinus je pravzaprav eksperiment čutečega tele...
# 1126067  Trg železniških storitev Naloga agencije na področju železnic je spremljanje konkurence na trgu storitev v potniškem in tovornem prometu. Če agencija ugotovi kršitve svobodne konkurence ali predpisov pri dodeljevanju vlakovnih poti ter zaračunavanju uporabnine, ukrepa v skladu z Zakonom o železn...
# 2598465  Uporablja se kot osnovni premaz pred nanašanjem izravnalne mase ter pri pripravi mavčno-kartonskih, cementno-vlaknenih plošč in mineralnih površin za nadaljno obdelavo. Pred uporabo je treba BK-Podlago razredčiti z vodo v razmerju BK-Podlaga:voda = 1:9. Čas sušenja pred nanosom barve znaša najma...
# 577848   Mehanizem bo imel ključno vlogo pri tem, da si bo lahko Evropa lažje opomogla od gospodarskih in socialnih posledic pandemije, poleg tega pa bo prispeval k večji odpornosti evropskih gospodarstev in družb ter zagotovitvi zelenega in digitalnega prehoda. Vključevati morajo celovite reforme in zan...
# 739258   Prof. dr. Dušan Mramor Nekdanji minister za finance RS in redni profesor na Ekonomski fakulteti na Univerzi v Ljubljani Primož Praper Direktor Eutrip d.o.o. Danica Purg Predsednica in dekanja Poslovne šole IEDC Bled Iztok Seljak Direktor Hidria Holding d.o.o. Alenka Suhadolnik Generalna direktor...
# 1545007  Avatarke: virtualni in realni prostori Iniciativa ČIPke je v sodelovanju z RogLabom in Rampa Laboratorijem s Kersnikove pripravila delavnico Avatarke – virtualni in realni prostori pod mentorskim vodstvom Tank Thunderbird, mednarodno priznane medijske umetnice. Udeleženke so se učile modulacije ...
# 1668855  Oglejte si prisrčne fotografije, ki jih z nami delijo strokovne delavke vrtca iz Hrvaške (Dječji vrtić Radost) in vrtca iz Litve (Vilnius kindergarten "Aitvaras"). Ob spoznavanju druge teme - Jaz in moja družina, otroci izvajajo številne zanimive dejavnosti, s katerimi spoznavajo svojo družino i...
#
#          en_length  sl_length
# 1548798        245        133
# 84755           94         34
# 2562108        240        212
# 348403         205         55
# 2031466         98         27
# 609292         112        132
# 1805773        160         89
# 1737177        104         74
# 1993535        625         25
# 930061         139          3
# 2223005        101        122
# 71124          333        319
# 245429         612         67
# 806658         145        116
# 1126067        409        277
# 2598465        145        291
# 577848         423        393
# 739258         617        583
# 1545007        204        185
# 1668855        263        324

# %%
# Discard instances document that are from different domains
corpus_df = corpus_df[corpus_df["same_domains"] == "yes"]
corpus_df.describe(include="all")
# Out:
#        biroamer_entities translation_direction  \
# count             104853                104853
# unique                 2                     2
# top                   No               sl-orig
# freq               91558                 92925
# mean                 NaN                   NaN
# std                  NaN                   NaN
# min                  NaN                   NaN
# 25%                  NaN                   NaN
# 50%                  NaN                   NaN
# 75%                  NaN                   NaN
# max                  NaN                   NaN
#
#                               en_source en_var_doc en_var_dom  \
# count                            104853     104853     104853
# unique                           104853          4          4
# top     http://15.liffe.si/?lang_chg=en          B          B
# freq                                  1      40907      56596
# mean                                NaN        NaN        NaN
# std                                 NaN        NaN        NaN
# min                                 NaN        NaN        NaN
# 25%                                 NaN        NaN        NaN
# 50%                                 NaN        NaN        NaN
# 75%                                 NaN        NaN        NaN
# max                                 NaN        NaN        NaN
#
#                                                              sl_source  \
# count                                                           104853
# unique                                                           95040
# top     https://www.sofascore.com/sl/ekipa/nogomet/viktoria-plzen/4502
# freq                                                                 9
# mean                                                               NaN
# std                                                                NaN
# min                                                                NaN
# 25%                                                                NaN
# 50%                                                                NaN
# 75%                                                                NaN
# max                                                                NaN
#
#           en_domain    sl_domain same_domains        different_domains  \
# count        104853       104853       104853                   104853
# unique         5980         5980            1                     5980
# top     oblacila.si  oblacila.si          yes  oblacila.si oblacila.si
# freq           3949         3949       104853                     3949
# mean            NaN          NaN          NaN                      NaN
# std             NaN          NaN          NaN                      NaN
# min             NaN          NaN          NaN                      NaN
# 25%             NaN          NaN          NaN                      NaN
# 50%             NaN          NaN          NaN                      NaN
# 75%             NaN          NaN          NaN                      NaN
# max             NaN          NaN          NaN                      NaN
#
#         average_score  \
# count   104853.000000
# unique            NaN
# top               NaN
# freq              NaN
# mean         0.886736
# std          0.068253
# min          0.502000
# 25%          0.851900
# 50%          0.904000
# 75%          0.936750
# max          0.990500
#
#                                                                                                                                                                                                                                                                                                              en_doc  \
# count                                                                                                                                                                                                                                                                                                        104853
# unique                                                                                                                                                                                                                                                                                                       104853
# top     It went out with a bang. The evening sparkled with glitter and gold and Gallus Hall hosted yet another closing and awards ceremony of the jubilee Ljubljana International Film Festival. Dashing in their black ties and led by eminent conductor Helmut Imig, the RTV Slovenia Symphony Orchestra perfo...
# freq                                                                                                                                                                                                                                                                                                              1
# mean                                                                                                                                                                                                                                                                                                            NaN
# std                                                                                                                                                                                                                                                                                                             NaN
# min                                                                                                                                                                                                                                                                                                             NaN
# 25%                                                                                                                                                                                                                                                                                                             NaN
# 50%                                                                                                                                                                                                                                                                                                             NaN
# 75%                                                                                                                                                                                                                                                                                                             NaN
# max                                                                                                                                                                                                                                                                                                             NaN
#
#                                                                                                    sl_doc  \
# count                                                                                              104853
# unique                                                                                              94869
# top     Ali se strinjate, da na vaš računalnik namestimo piškotke in omogočimo pravilno delovanje strani?
# freq                                                                                                   23
# mean                                                                                                  NaN
# std                                                                                                   NaN
# min                                                                                                   NaN
# 25%                                                                                                   NaN
# 50%                                                                                                   NaN
# 75%                                                                                                   NaN
# max                                                                                                   NaN
#
#             en_length      sl_length
# count   104853.000000  104853.000000
# unique            NaN            NaN
# top               NaN            NaN
# freq              NaN            NaN
# mean       487.442829     495.742315
# std       2058.219685    2462.451608
# min         79.000000       2.000000
# 25%        128.000000      92.000000
# 50%        210.000000     166.000000
# 75%        392.000000     333.000000
# max     106893.000000   98530.000000

# %%
# Save the dataframe to csv
corpus_df.to_csv("Macocu-sl-en-doc-format.csv", sep= "\t")
